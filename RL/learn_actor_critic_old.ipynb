# %% [markdown]
# # Learn Actor Crititc

# %%
import numpy as np
import mediapy as media
import matplotlib.pyplot as plt


import os
# os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".60"

# Optionally, force JAX to preallocate memory.
# os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "true"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

# Setup environment variable for Nvidia GPU acceleration
os.environ['XLA_FLAGS'] = (
    '--xla_gpu_triton_gemm_any=True '
)
backend = 'gpu'
# backend = 'METAL'
# backend = 'cpu'

import jax
from jax import numpy as jp
import flax
import flax.linen as nn
import optax


# Enable compliation catch
jax.config.update("jax_compilation_cache_dir", "./jax_cache")
jax.config.update("jax_persistent_cache_min_entry_size_bytes", 0)
jax.config.update("jax_persistent_cache_min_compile_time_secs", 5)
# jax.config.update("jax_explain_cache_misses", True)

# Debug Nan
jax.config.update("jax_debug_nans", False)


# More legible printing from numpy.
jp.set_printoptions(precision=4, suppress=True, linewidth=100)

import mujoco
import mujoco.mjx as mjx
from mujoco.mjx._src import scan
from mujoco.mjx._src import types

# More legible printing from numpy.
np.set_printoptions(precision=4, suppress=True, linewidth=100)

from IPython.display import clear_output
clear_output()

device = jax.devices(backend=backend)[0]

model_path = '../model/inverted_pendulum.xml'

# Single step
mjx_step = jax.jit(mjx.step, backend=backend)



# mjx_multiple_steps = jax.jit(multiple_steps, backend=backend, )

# %% [markdown]
# ## Load Model

# %%
from mujoco.mjx._src.biomtu import acceleration_mtu

mj_model = mujoco.MjModel.from_xml_path(model_path)
mjx_model = mjx.put_model(mj_model,device=device)

# Disable tendon
opt = mjx_model.opt.replace(disableflags = mjx_model.opt.disableflags |mujoco.mjtDisableBit.mjDSBL_PASSIVE)
mjx_model = mjx_model.replace(opt=opt)

mjx_data = mjx.make_data(mjx_model)
mj_data = mujoco.MjData(mj_model)

# Load the Keyframe
# mjx_data = mjx_data.replace(qpos = mj_model.key_qpos[0])
# mj_data.qpos = mj_model.key_qpos[0]

# Calculate equilibrum
# mjx_data = acceleration_mtu.calc_equilibrium(mjx_model, mjx_data)
mjx_data = mjx_step(mjx_model, mjx_data)

# %% [markdown]
# ## Control Neural Network and Critic Neural Network
# For now this NN will only work for the inverted pendulum

# %%
class Controller_NN(nn.Module):
    out_dims = 1
    def setup(self):
        # Features means the output dimension
        self.linear1 = nn.Dense(features=400)
        self.linear2 = nn.Dense(features=400)
        self.linear3 = nn.Dense(features=400)
        self.linear4 = nn.Dense(features=400)
        # The last layer will output the mean and logstd
        self.linear5 = nn.Dense(features=self.out_dims*2)
        
    
    def __call__(self, x, key):
        x = self.linear1(x)
        x = nn.relu(x)
        x = self.linear2(x)
        x = nn.relu(x)
        x = self.linear3(x)
        x = nn.relu(x)
        x = self.linear4(x)
        x = nn.relu(x)
        x = self.linear5(x)
        # The last layer of the neural requires samping
        mean = x[0]
        logstd = x[1]
        std = jp.exp(logstd)
        # samples = jp.clip(jax.random.normal(key)*std*0.3 + mean, -3, 3)
        samples = jax.random.normal(key)*std*0.3 + mean
        
        return samples, mean, logstd

# Test the neural network
controller = Controller_NN()

# Init the model
key = jax.random.key(2024)
sub_keys = jax.random.split(key,1)
# The second parameter is the dommy input
controller_params = controller.init(key,jp.empty([1, mjx_model.nq*2]),sub_keys[0])
# print(params)
jit_controller = jax.jit(lambda params, states, key : controller.apply(params, states, key))

class Critic_NN(nn.Module):

    def setup(self):
        # Features means the output dimension
        self.linear1 = nn.Dense(features=400)
        self.linear2 = nn.Dense(features=400)
        self.linear3 = nn.Dense(features=400)
        self.linear4 = nn.Dense(features=400)
        # The last layer will output the mean and logstd
        self.linear5 = nn.Dense(features=1)
        
    
    def __call__(self, x):
        x = self.linear1(x)
        x = nn.relu(x)
        x = self.linear2(x)
        x = nn.relu(x)
        x = self.linear3(x)
        x = nn.relu(x)
        x = self.linear4(x)
        x = nn.relu(x)
        x = self.linear5(x)
        # The last layer of the neural requires samping
        return -nn.relu(x)

critic = Critic_NN()

# Init the critic neural network by providing the input dummy. The input dummy defines the input shape
key = jax.random.split(sub_keys[0],1)[0]
sub_key = jax.random.split(key,1)[0]

# The input for the qcritic neural network should be observations and actions
# For the obs=mjx_model.nq*2, actions=1
critic_params = critic.init(key, jp.empty([1,mjx_model.nq*2]))
jit_critic = jax.jit(lambda params, state_acts: critic.apply(params, state_acts))

# Test the two neural networks
print(jit_controller(controller_params, jp.ones(mjx_model.nq*2), sub_keys[0]))
print(jit_critic(critic_params, jp.ones(mjx_model.nq*2)))
# Out:
# (Array(0.4321, dtype=float32), Array(0.1207, dtype=float32), Array(-0.1315, dtype=float32))
# [-0.047]

# %% [markdown]
# ## Experience Control

# %%
from dataclasses import dataclass
import functools


# Register the Experience class as pytree
@functools.partial(jax.tree_util.register_dataclass,
                   data_fields=['states', 'next_states', 'actions', 'rewards'],
                   meta_fields=[])
@dataclass
class Experience(object):
    states : jax.Array
    next_states : jax.Array
    actions : jax.Array
    rewards : jax.Array
    # dones: jax.Array
    
    # def __init__(self, state, next_state, action, reward):
    #     self.state = state
    #     self.next_state = next_state
    #     self.action = action
    #     self.reward = reward



@functools.partial(jax.tree_util.register_dataclass,
                   data_fields=['max_size', 'state_shape', 'action_shape', 'reward_shape'],
                   meta_fields=[])
@dataclass(frozen=True)
class Memory_settings():
    max_size     : jax.Array
    state_shape  : jax.Array
    action_shape : jax.Array
    reward_shape : jax.Array


class Memory(): 
    
    @staticmethod
    def append_fn(exp_item, exp_pool_item):
        return jp.concatenate([exp_item, exp_pool_item],axis=0)
    
    @staticmethod
    def trim_fn(exp_pool_item, length):
        return exp_pool_item[:length]
    
    @staticmethod
    def sample_fn(exp_pool_item, index):
        return exp_pool_item[index]
    
    staticmethod
    @functools.partial(jax.jit, static_argnames="settings")
    def add_exp(settings:Memory_settings, exp_pool:Experience, exp:Experience):
        exp.states = jp.reshape(exp.states,(-1, settings.state_shape))
        exp.next_states = jp.reshape(exp.next_states,(-1, settings.state_shape))
        exp.actions = jp.reshape(exp.actions, (-1, settings.action_shape))
        exp.rewards = jp.reshape(exp.rewards, (-1, settings.reward_shape))
        
        if(exp_pool == None):
            exp_pool = exp
        else:
            exp_pool = jax.tree.map(Memory.append_fn, exp, exp_pool)
            
        len = exp_pool.states.shape[0]
        
        # Forget the outdated memory
        if(len> settings.max_size):
            exp_pool = jax.tree.map(lambda x: Memory.trim_fn(x, settings.max_size), exp_pool)
        
        return exp_pool
        
    @staticmethod
    @functools.partial(jax.jit, static_argnames="batch_size")
    def sample(exp_pool, batch_size, key)-> Experience :
        index = jax.random.choice(
            key,
            jp.arange(exp_pool.states.shape[0]),
            shape = (batch_size,),
            replace=False
        )
        return jax.tree.map(lambda x: Memory.sample_fn(x, index), exp_pool)

# %% [markdown]
# ## Multi-steps forward simulation

# %%
def step_fn(carry, _):
    data, model = carry
    new_data = mjx.step(model, data)
    new_carry = (new_data, model)
    return new_carry, _

def multiple_steps(model, data):
    init_carry = (data, model)
    y, _ = jax.lax.scan(step_fn, init_carry, None, length=10)
    new_data = y[0]
    return new_data

def nn_mjx_one_step(nn_params, model, data, key):
    states = jp.concatenate([data.qpos, data.qvel])
    act, mean, dev = jit_controller(nn_params, states, key)
    # Generate the next key
    new_key = jax.random.split(key,1)[0]
    data = data.replace(ctrl = jp.array([act]))
    new_data = mjx.step(model, data)
    return new_data, new_key, act

@jax.jit
def jit_nn_mjx_one_step_no_random(nn_params, model, data, key):
    states = jp.concatenate([data.qpos, data.qvel])
    act, mean, dev = jit_controller(nn_params, states, key)
    # Generate the next key
    new_key = jax.random.split(key,1)[0]
    data = data.replace(ctrl = jp.array([mean]))
    new_data = mjx.step(model, data)
    return new_data, new_key, mean

def nn_step_fn(carry, _):
    nn_params, model, data, key = carry
    new_data, new_key, act = nn_mjx_one_step(nn_params, model, data, key)
    new_carry = (nn_params, model, new_data, new_key)
    # Calculate reward
    state = jp.stack([data.qpos, data.qvel], axis=1).flatten()
    next_state = jp.stack([new_data.qpos, data.qvel], axis=1).flatten()
    action = act
    reward = -new_data.qpos[1]**2
    experience = Experience(state, next_state, action, reward)
    
    return new_carry, experience

def decay_sum_scan(x, decay):
    def f(sxtm1, xt):
        b = xt + decay * sxtm1
        return b, b
    return jax.lax.scan(f, jp.zeros(x.shape[1:]), x)[1]

@jax.jit
def jit_nn_multi_steps(nn_params, model, data, key):
    repeat_length = 5
    init_carry = (nn_params, model, data, key)
    y, experience = jax.lax.scan(nn_step_fn, init_carry, None, length=repeat_length)
    new_data = y[2]
    new_key = y[3]
    
    return new_data, new_key, experience

@jax.jit
def jit_v_nn_multi_steps(nn_params, model, data, key):
    return jax.vmap(jit_nn_multi_steps, in_axes=(None, None, 0, 0))(nn_params, model, data, key)

# This function generate
@jax.jit
def jit_vv_nn_multi_steps(nn_params, model, data, key):
    return jax.vmap(jit_v_nn_multi_steps, in_axes=(None, None, None, 1))(nn_params, model, data, key)

# %% [markdown]
# ## Short Horizon Simulation & Gradient

# %% [markdown]
# ## Environment Control

# %%
# @jax.jit
def reset(model, batch_size):
    batch_dummy = jp.zeros(batch_size)
    v_make_data = jax.jit(jax.vmap(lambda model, batch_dummy: mjx.make_data(model), in_axes=(None,0),out_axes=0))
    new_datas = v_make_data(model, batch_dummy)
    return new_datas

# %% [markdown]
# ## Visualize the model and controller

# %%
import mujoco.viewer
import time


mjx_data = mjx.make_data(mjx_model)
mj_data = mujoco.MjData(mj_model)
previous_frame_time = time.time()
i = 0
key = jax.random.key(334)
with mujoco.viewer.launch_passive(mj_model, mj_data) as viewer:
    while viewer.is_running():
        # Update mjx_data from mj_data. The mj_data was modified by the viewer
        # mjx_data = mjx_data.replace(ctrl=mj_data.ctrl, xfrc_applied=mj_data.xfrc_applied)
        # Use the nerual network to generate ctrl signal
        # Generate key
        mjx_data = mjx_data.replace(xfrc_applied=jp.array(mj_data.xfrc_applied, dtype=jp.float32))
        mjx_data = mjx_data.replace(
            qpos= jp.array(mj_data.qpos, dtype=jp.float32),
            qvel= jp.array(mj_data.qvel, dtype=jp.float32),
            time = jp.array(mj_data.time, dtype=jp.float32))
        
        # Update mjx_model from mj_model
        mjx_model = mjx_model.tree_replace({
            'opt.gravity': jp.array(mj_model.opt.gravity, dtype=jp.float32),
            'opt.tolerance': jp.array(mj_model.opt.tolerance, dtype=jp.float32),
            'opt.ls_tolerance': jp.array(mj_model.opt.ls_tolerance, dtype=jp.float32),
            'opt.timestep': jp.array(mj_model.opt.timestep, dtype=jp.float32),
        })
        
        key = jax.random.split(key,1)[0]
        # mjx_data = mjx_step(mjx_model, mjx_data)
        # mjx_data, loss, exp = jit_nn_multi_steps(controller_params, mjx_model, mjx_data, key)
        mjx_data, key, act = jit_nn_mjx_one_step_no_random(controller_params, mjx_model, mjx_data, key)
        mjx.get_data_into(mj_data, mj_model, mjx_data)
        
        # Record the current time at the start of this frame
        current_frame_time = time.time()
    
        # Calculate the difference in time from the last frame
        time_between_frames = current_frame_time - previous_frame_time
    
        # Print the time between frames
        print(f"Time between frames: {time_between_frames} seconds")
        previous_frame_time = current_frame_time
        
        # print("ACT:", mjx_data.biomtu.act)
        # print(mjx_data.qpos)
        # print(mjx_data.sensordata)
        # print(len(mjx_data.qvel))
        viewer.sync()
# Out:
# Time between frames: 0.15021133422851562 seconds
# Time between frames: 0.007979631423950195 seconds
# Time between frames: 0.008025884628295898 seconds
# Time between frames: 0.008130550384521484 seconds
# Time between frames: 0.006911039352416992 seconds
# Time between frames: 0.0066525936126708984 seconds
# Time between frames: 0.0074231624603271484 seconds
# Time between frames: 0.006432294845581055 seconds
# Time between frames: 0.006772518157958984 seconds
# Time between frames: 0.00892949104309082 seconds
# Time between frames: 0.012923240661621094 seconds
# Time between frames: 0.012794017791748047 seconds
# Time between frames: 0.01041865348815918 seconds
# Time between frames: 0.011100053787231445 seconds
# Time between frames: 0.010301589965820312 seconds
# Time between frames: 0.010606765747070312 seconds
# Time between frames: 0.006689548492431641 seconds
# Time between frames: 0.008092641830444336 seconds
# Time between frames: 0.006643533706665039 seconds
# Time between frames: 0.007639408111572266 seconds
# Time between frames: 0.007340431213378906 seconds
# Time between frames: 0.009990930557250977 seconds
# Time between frames: 0.009249448776245117 seconds
# Time between frames: 0.009239435195922852 seconds
# Time between frames: 0.011198997497558594 seconds
# Time between frames: 0.010343551635742188 seconds
# Time between frames: 0.010299921035766602 seconds
# Time between frames: 0.009694576263427734 seconds
# Time between frames: 0.011815547943115234 seconds
# Time between frames: 0.00917816162109375 seconds
# Time between frames: 0.01148843765258789 seconds
# Time between frames: 0.009679794311523438 seconds
# Time between frames: 0.010287046432495117 seconds
# Time between frames: 0.00963282585144043 seconds
# Time between frames: 0.011404991149902344 seconds
# Time between frames: 0.009464502334594727 seconds
# Time between frames: 0.01054835319519043 seconds
# Time between frames: 0.010144472122192383 seconds
# Time between frames: 0.010957479476928711 seconds
# Time between frames: 0.010094404220581055 seconds
# Time between frames: 0.011316776275634766 seconds
# Time between frames: 0.009254932403564453 seconds
# Time between frames: 0.010304450988769531 seconds
# Time between frames: 0.010281085968017578 seconds
# Time between frames: 0.01168060302734375 seconds
# Time between frames: 0.010094642639160156 seconds
# Time between frames: 0.010960817337036133 seconds
# Time between frames: 0.009840011596679688 seconds
# Time between frames: 0.010825872421264648 seconds
# Time between frames: 0.009498357772827148 seconds
# Time between frames: 0.011384248733520508 seconds
# Time between frames: 0.009241819381713867 seconds
# Time between frames: 0.010761499404907227 seconds
# Time between frames: 0.01013326644897461 seconds
# Time between frames: 0.011230707168579102 seconds
# Time between frames: 0.00969696044921875 seconds
# Time between frames: 0.010866641998291016 seconds
# Time between frames: 0.009704351425170898 seconds
# Time between frames: 0.010569572448730469 seconds
# Time between frames: 0.010311126708984375 seconds
# Time between frames: 0.011429071426391602 seconds
# Time between frames: 0.009686470031738281 seconds
# Time between frames: 0.010713338851928711 seconds
# Time between frames: 0.010215997695922852 seconds
# Time between frames: 0.011116266250610352 seconds
# Time between frames: 0.010213851928710938 seconds
# Time between frames: 0.011373281478881836 seconds
# Time between frames: 0.009238481521606445 seconds
# Time between frames: 0.010755777359008789 seconds
# Time between frames: 0.009870767593383789 seconds
# Time between frames: 0.010529518127441406 seconds
# Time between frames: 0.009773731231689453 seconds
# Time between frames: 0.011015653610229492 seconds
# Time between frames: 0.010025501251220703 seconds
# Time between frames: 0.011179447174072266 seconds
# Time between frames: 0.0098724365234375 seconds
# Time between frames: 0.011186361312866211 seconds
# Time between frames: 0.009010076522827148 seconds
# Time between frames: 0.010912418365478516 seconds
# Time between frames: 0.010519742965698242 seconds
# Time between frames: 0.011230707168579102 seconds
# Time between frames: 0.009930133819580078 seconds
# Time between frames: 0.011202812194824219 seconds
# Time between frames: 0.009556770324707031 seconds
# Time between frames: 0.011377811431884766 seconds
# Time between frames: 0.010335445404052734 seconds
# Time between frames: 0.01011037826538086 seconds
# Time between frames: 0.009310483932495117 seconds
# Time between frames: 0.011071920394897461 seconds
# Time between frames: 0.00981593132019043 seconds
# Time between frames: 0.010751962661743164 seconds
# Time between frames: 0.010166406631469727 seconds
# Time between frames: 0.011376380920410156 seconds
# Time between frames: 0.009618043899536133 seconds
# Time between frames: 0.010815143585205078 seconds
# Time between frames: 0.010461568832397461 seconds
# Time between frames: 0.011010408401489258 seconds
# Time between frames: 0.009895086288452148 seconds
# Time between frames: 0.010770082473754883 seconds
# Time between frames: 0.009070873260498047 seconds
# Time between frames: 0.008824586868286133 seconds
# Time between frames: 0.009864568710327148 seconds
# Time between frames: 0.009277582168579102 seconds
# Time between frames: 0.011023998260498047 seconds
# Time between frames: 0.010008096694946289 seconds
# Time between frames: 0.011322975158691406 seconds
# Time between frames: 0.009823083877563477 seconds
# Time between frames: 0.011071443557739258 seconds
# Time between frames: 0.009358644485473633 seconds
# Time between frames: 0.010560750961303711 seconds
# Time between frames: 0.009882211685180664 seconds
# Time between frames: 0.010617733001708984 seconds
# Time between frames: 0.010391473770141602 seconds
# Time between frames: 0.010933160781860352 seconds
# Time between frames: 0.010274171829223633 seconds
# Time between frames: 0.010783910751342773 seconds
# Time between frames: 0.009650468826293945 seconds
# Time between frames: 0.011103153228759766 seconds
# Time between frames: 0.00992894172668457 seconds
# Time between frames: 0.010358333587646484 seconds
# Time between frames: 0.010219573974609375 seconds
# Time between frames: 0.011384010314941406 seconds
# Time between frames: 0.010090351104736328 seconds
# Time between frames: 0.010758161544799805 seconds
# Time between frames: 0.009913921356201172 seconds
# Time between frames: 0.01097249984741211 seconds
# Time between frames: 0.009929418563842773 seconds
# Time between frames: 0.01147603988647461 seconds
# Time between frames: 0.009506940841674805 seconds
# Time between frames: 0.010749340057373047 seconds
# Time between frames: 0.01045370101928711 seconds
# Time between frames: 0.010825395584106445 seconds
# Time between frames: 0.009801149368286133 seconds
# Time between frames: 0.011136054992675781 seconds
# Time between frames: 0.009566307067871094 seconds
# Time between frames: 0.010710716247558594 seconds
# Time between frames: 0.009895801544189453 seconds
# Time between frames: 0.01145792007446289 seconds
# Time between frames: 0.010092973709106445 seconds
# Time between frames: 0.01597738265991211 seconds
# Time between frames: 0.013199090957641602 seconds
# Time between frames: 0.01236581802368164 seconds
# Time between frames: 0.011923789978027344 seconds
# Time between frames: 0.010122299194335938 seconds
# Time between frames: 0.011244058609008789 seconds
# Time between frames: 0.01387786865234375 seconds
# Time between frames: 0.011518001556396484 seconds
# Time between frames: 0.010124683380126953 seconds
# Time between frames: 0.01154017448425293 seconds
# Time between frames: 0.009417295455932617 seconds
# Time between frames: 0.011431217193603516 seconds
# Time between frames: 0.010003089904785156 seconds
# Time between frames: 0.01079702377319336 seconds
# Time between frames: 0.009881258010864258 seconds
# Time between frames: 0.011148691177368164 seconds
# Time between frames: 0.009662389755249023 seconds
# Time between frames: 0.010697364807128906 seconds
# Time between frames: 0.009836196899414062 seconds
# Time between frames: 0.01144719123840332 seconds
# Time between frames: 0.00991058349609375 seconds
# Time between frames: 0.01103067398071289 seconds
# Time between frames: 0.009984493255615234 seconds
# Time between frames: 0.01012563705444336 seconds
# Time between frames: 0.010192394256591797 seconds
# Time between frames: 0.011242389678955078 seconds
# Time between frames: 0.01018524169921875 seconds
# Time between frames: 0.01047372817993164 seconds
# Time between frames: 0.010211944580078125 seconds
# Time between frames: 0.011312007904052734 seconds
# Time between frames: 0.010028839111328125 seconds
# Time between frames: 0.012171030044555664 seconds
# Time between frames: 0.006140232086181641 seconds
# Time between frames: 0.006383419036865234 seconds
# Time between frames: 0.009211063385009766 seconds
# Time between frames: 0.01089620590209961 seconds
# Time between frames: 0.00963592529296875 seconds
# Time between frames: 0.011082887649536133 seconds
# Time between frames: 0.010032176971435547 seconds
# Time between frames: 0.010585546493530273 seconds
# Time between frames: 0.009748220443725586 seconds
# Time between frames: 0.011359453201293945 seconds
# Time between frames: 0.009366035461425781 seconds
# Time between frames: 0.010439634323120117 seconds
# Time between frames: 0.010385513305664062 seconds
# Time between frames: 0.011421918869018555 seconds
# Time between frames: 0.009851694107055664 seconds
# Time between frames: 0.011065959930419922 seconds
# Time between frames: 0.009658336639404297 seconds
# Time between frames: 0.010967731475830078 seconds
# Time between frames: 0.009645462036132812 seconds
# Time between frames: 0.009764671325683594 seconds
# Time between frames: 0.010483503341674805 seconds
# Time between frames: 0.010926008224487305 seconds
# Time between frames: 0.010784149169921875 seconds
# Time between frames: 0.010946273803710938 seconds
# Time between frames: 0.009252309799194336 seconds
# Time between frames: 0.011388063430786133 seconds
# Time between frames: 0.009605884552001953 seconds
# Time between frames: 0.010942220687866211 seconds
# Time between frames: 0.010528802871704102 seconds
# Time between frames: 0.010935544967651367 seconds
# Time between frames: 0.009172677993774414 seconds
# Time between frames: 0.010502099990844727 seconds
# Time between frames: 0.010541439056396484 seconds
# Time between frames: 0.011012792587280273 seconds
# Time between frames: 0.009995222091674805 seconds
# Time between frames: 0.011193275451660156 seconds
# Time between frames: 0.009345531463623047 seconds
# Time between frames: 0.011061429977416992 seconds
# Time between frames: 0.01002955436706543 seconds
# Time between frames: 0.010819435119628906 seconds
# Time between frames: 0.009959697723388672 seconds
# Time between frames: 0.010902166366577148 seconds
# Time between frames: 0.00964665412902832 seconds
# Time between frames: 0.010683774948120117 seconds
# Time between frames: 0.010212421417236328 seconds
# Time between frames: 0.011233806610107422 seconds
# Time between frames: 0.00965118408203125 seconds
# Time between frames: 0.010994434356689453 seconds
# Time between frames: 0.009812116622924805 seconds
# Time between frames: 0.010628938674926758 seconds
# Time between frames: 0.009900569915771484 seconds
# Time between frames: 0.011378288269042969 seconds
# Time between frames: 0.00991511344909668 seconds
# Time between frames: 0.011223316192626953 seconds
# Time between frames: 0.010166645050048828 seconds
# Time between frames: 0.011214017868041992 seconds
# Time between frames: 0.009898185729980469 seconds
# Time between frames: 0.010379791259765625 seconds
# Time between frames: 0.009695291519165039 seconds
# Time between frames: 0.010597467422485352 seconds
# Time between frames: 0.009904861450195312 seconds
# Time between frames: 0.011399269104003906 seconds
# Time between frames: 0.00927877426147461 seconds
# Time between frames: 0.01045989990234375 seconds
# Time between frames: 0.010290384292602539 seconds
# Time between frames: 0.009445905685424805 seconds
# Time between frames: 0.009346485137939453 seconds
# Time between frames: 0.009343147277832031 seconds
# Time between frames: 0.011243820190429688 seconds
# Time between frames: 0.009330511093139648 seconds
# Time between frames: 0.011070966720581055 seconds
# Time between frames: 0.00993967056274414 seconds
# Time between frames: 0.010851144790649414 seconds
# Time between frames: 0.010468721389770508 seconds
# Time between frames: 0.011324167251586914 seconds
# Time between frames: 0.009381532669067383 seconds
# Time between frames: 0.011077404022216797 seconds
# Time between frames: 0.009786367416381836 seconds
# Time between frames: 0.010911226272583008 seconds
# Time between frames: 0.009429216384887695 seconds
# Time between frames: 0.01083683967590332 seconds
# Time between frames: 0.009869098663330078 seconds
# Time between frames: 0.008787870407104492 seconds
# Time between frames: 0.009757041931152344 seconds
# Time between frames: 0.009737014770507812 seconds
# Time between frames: 0.011082887649536133 seconds
# Time between frames: 0.009867429733276367 seconds
# Time between frames: 0.01139068603515625 seconds
# Time between frames: 0.009175539016723633 seconds
# Time between frames: 0.010591745376586914 seconds
# Time between frames: 0.010282039642333984 seconds
# Time between frames: 0.010666131973266602 seconds
# Time between frames: 0.010421991348266602 seconds
# Time between frames: 0.011222124099731445 seconds
# Time between frames: 0.01015329360961914 seconds
# Time between frames: 0.010664701461791992 seconds
# Time between frames: 0.009577512741088867 seconds
# Time between frames: 0.011285781860351562 seconds
# Time between frames: 0.009234189987182617 seconds
# Time between frames: 0.010904788970947266 seconds
# Time between frames: 0.010460376739501953 seconds
# Time between frames: 0.010938882827758789 seconds
# Time between frames: 0.00962686538696289 seconds
# Time between frames: 0.011106491088867188 seconds
# Time between frames: 0.009638071060180664 seconds
# Time between frames: 0.011058330535888672 seconds
# Time between frames: 0.009928464889526367 seconds
# Time between frames: 0.01077127456665039 seconds
# Time between frames: 0.010076522827148438 seconds
# Time between frames: 0.011032819747924805 seconds
# Time between frames: 0.00947260856628418 seconds
# Time between frames: 0.01047658920288086 seconds
# Time between frames: 0.010325908660888672 seconds
# Time between frames: 0.01149606704711914 seconds
# Time between frames: 0.009633541107177734 seconds
# Time between frames: 0.01088261604309082 seconds
# Time between frames: 0.009866714477539062 seconds
# Time between frames: 0.010901689529418945 seconds
# Time between frames: 0.010485649108886719 seconds
# Time between frames: 0.010919332504272461 seconds
# Time between frames: 0.009657144546508789 seconds
# Time between frames: 0.010924339294433594 seconds
# Time between frames: 0.009470939636230469 seconds
# Time between frames: 0.011111736297607422 seconds
# Time between frames: 0.009805440902709961 seconds
# Time between frames: 0.011135101318359375 seconds
# Time between frames: 0.009540796279907227 seconds
# Time between frames: 0.010495662689208984 seconds
# Time between frames: 0.010231256484985352 seconds
# Time between frames: 0.011296510696411133 seconds
# Time between frames: 0.009926557540893555 seconds
# Time between frames: 0.011924028396606445 seconds
# Time between frames: 0.012280941009521484 seconds
# Time between frames: 0.010933399200439453 seconds
# Time between frames: 0.010955333709716797 seconds
# Time between frames: 0.00958108901977539 seconds
# Time between frames: 0.010576486587524414 seconds
# Time between frames: 0.010077714920043945 seconds
# Time between frames: 0.012045860290527344 seconds
# Time between frames: 0.010609865188598633 seconds
# Time between frames: 0.009910106658935547 seconds
# Time between frames: 0.010174989700317383 seconds
# Time between frames: 0.010911703109741211 seconds
# Time between frames: 0.009669065475463867 seconds
# Time between frames: 0.011286735534667969 seconds
# Time between frames: 0.010219097137451172 seconds
# Time between frames: 0.011459827423095703 seconds
# Time between frames: 0.009736776351928711 seconds
# Time between frames: 0.00974726676940918 seconds
# Time between frames: 0.009150266647338867 seconds
# Time between frames: 0.010871410369873047 seconds
# Time between frames: 0.009527206420898438 seconds
# Time between frames: 0.010939598083496094 seconds
# Time between frames: 0.01054239273071289 seconds
# Time between frames: 0.012264013290405273 seconds
# Time between frames: 0.009557008743286133 seconds
# Time between frames: 0.0102081298828125 seconds
# Time between frames: 0.009439468383789062 seconds
# Time between frames: 0.010719776153564453 seconds
# Time between frames: 0.010404348373413086 seconds
# Time between frames: 0.011733055114746094 seconds
# Time between frames: 0.010108232498168945 seconds
# Time between frames: 0.009978532791137695 seconds
# Time between frames: 0.009395122528076172 seconds
# Time between frames: 0.010993003845214844 seconds
# Time between frames: 0.009410619735717773 seconds
# Time between frames: 0.009415149688720703 seconds
# Time between frames: 0.00956273078918457 seconds
# Time between frames: 0.009078264236450195 seconds
# Time between frames: 0.010725736618041992 seconds
# Time between frames: 0.01011037826538086 seconds
# Time between frames: 0.01044774055480957 seconds
# Time between frames: 0.010267257690429688 seconds
# Time between frames: 0.006798505783081055 seconds
# Time between frames: 0.006792306900024414 seconds
# Time between frames: 0.0065538883209228516 seconds
# Time between frames: 0.00615382194519043 seconds
# Time between frames: 0.006521463394165039 seconds
# Time between frames: 0.007313251495361328 seconds
# Time between frames: 0.006659507751464844 seconds
# Time between frames: 0.0067555904388427734 seconds
# Time between frames: 0.006442070007324219 seconds
# Time between frames: 0.006493568420410156 seconds
# Time between frames: 0.00661468505859375 seconds
# Time between frames: 0.010448217391967773 seconds
# Time between frames: 0.01090383529663086 seconds
# Time between frames: 0.010511398315429688 seconds
# Time between frames: 0.012431621551513672 seconds
# Time between frames: 0.009431838989257812 seconds
# Time between frames: 0.010118484497070312 seconds
# Time between frames: 0.010771512985229492 seconds
# Time between frames: 0.01011800765991211 seconds
# Time between frames: 0.009371042251586914 seconds
# Time between frames: 0.011265993118286133 seconds
# Time between frames: 0.009577035903930664 seconds
# Time between frames: 0.01111602783203125 seconds
# Time between frames: 0.008327484130859375 seconds
# Time between frames: 0.007032632827758789 seconds
# Time between frames: 0.006960391998291016 seconds
# Time between frames: 0.0058765411376953125 seconds
# Time between frames: 0.0064656734466552734 seconds
# Time between frames: 0.0066030025482177734 seconds
# Time between frames: 0.00654911994934082 seconds
# Time between frames: 0.006340980529785156 seconds
# Time between frames: 0.007505655288696289 seconds
# Time between frames: 0.010229110717773438 seconds
# Time between frames: 0.011043787002563477 seconds
# Time between frames: 0.009339332580566406 seconds
# Time between frames: 0.009135961532592773 seconds
# Time between frames: 0.009741544723510742 seconds
# Time between frames: 0.009229898452758789 seconds
# Time between frames: 0.010544538497924805 seconds
# Time between frames: 0.01011967658996582 seconds
# Time between frames: 0.011418819427490234 seconds
# Time between frames: 0.009400129318237305 seconds
# Time between frames: 0.009089946746826172 seconds
# Time between frames: 0.009552240371704102 seconds
# Time between frames: 0.00926661491394043 seconds
# Time between frames: 0.011099100112915039 seconds
# Time between frames: 0.010329008102416992 seconds
# Time between frames: 0.011501312255859375 seconds
# Time between frames: 0.009918451309204102 seconds
# Time between frames: 0.010805368423461914 seconds
# Time between frames: 0.009542226791381836 seconds
# Time between frames: 0.010450363159179688 seconds
# Time between frames: 0.009713411331176758 seconds
# Time between frames: 0.011723518371582031 seconds
# Time between frames: 0.009407520294189453 seconds
# Time between frames: 0.011135339736938477 seconds
# Time between frames: 0.009604454040527344 seconds
# Time between frames: 0.011865615844726562 seconds
# Time between frames: 0.009699583053588867 seconds
# Time between frames: 0.010794639587402344 seconds
# Time between frames: 0.009469270706176758 seconds
# Time between frames: 0.010471343994140625 seconds
# Time between frames: 0.009868621826171875 seconds
# Time between frames: 0.011811971664428711 seconds
# Time between frames: 0.009624719619750977 seconds
# Time between frames: 0.011335611343383789 seconds
# Time between frames: 0.009787797927856445 seconds
# Time between frames: 0.011485576629638672 seconds
# Time between frames: 0.009788751602172852 seconds
# Time between frames: 0.010967254638671875 seconds
# Time between frames: 0.009063959121704102 seconds
# Time between frames: 0.01159977912902832 seconds
# Time between frames: 0.009511947631835938 seconds
# Time between frames: 0.011204004287719727 seconds
# Time between frames: 0.00946187973022461 seconds
# Time between frames: 0.011721611022949219 seconds
# Time between frames: 0.009433269500732422 seconds
# Time between frames: 0.011185169219970703 seconds
# Time between frames: 0.009491682052612305 seconds
# Time between frames: 0.011571168899536133 seconds
# Time between frames: 0.009115934371948242 seconds
# Time between frames: 0.012000560760498047 seconds
# Time between frames: 0.009433269500732422 seconds
# Time between frames: 0.011112689971923828 seconds
# Time between frames: 0.009784460067749023 seconds
# Time between frames: 0.010360956192016602 seconds
# Time between frames: 0.009665966033935547 seconds
# Time between frames: 0.012444734573364258 seconds
# Time between frames: 0.012574911117553711 seconds
# Time between frames: 0.009249210357666016 seconds
# Time between frames: 0.011392354965209961 seconds
# Time between frames: 0.009584665298461914 seconds
# Time between frames: 0.011445760726928711 seconds
# Time between frames: 0.009847164154052734 seconds
# Time between frames: 0.012272357940673828 seconds
# Time between frames: 0.010139226913452148 seconds
# Time between frames: 0.011124610900878906 seconds
# Time between frames: 0.012415170669555664 seconds
# Time between frames: 0.009223461151123047 seconds
# Time between frames: 0.011805057525634766 seconds
# Time between frames: 0.009593486785888672 seconds
# Time between frames: 0.011111021041870117 seconds
# Time between frames: 0.009266138076782227 seconds
# Time between frames: 0.011913776397705078 seconds
# Time between frames: 0.009475946426391602 seconds
# Time between frames: 0.011416912078857422 seconds
# Time between frames: 0.009728431701660156 seconds
# Time between frames: 0.011224985122680664 seconds
# Time between frames: 0.008930444717407227 seconds
# Time between frames: 0.011540412902832031 seconds
# Time between frames: 0.009729862213134766 seconds
# Time between frames: 0.011167526245117188 seconds
# Time between frames: 0.009939193725585938 seconds
# Time between frames: 0.00933837890625 seconds
# Time between frames: 0.009070873260498047 seconds
# Time between frames: 0.009102344512939453 seconds
# Time between frames: 0.011504888534545898 seconds
# Time between frames: 0.009174108505249023 seconds
# Time between frames: 0.011039018630981445 seconds
# Time between frames: 0.009354114532470703 seconds
# Time between frames: 0.01181793212890625 seconds
# Time between frames: 0.00922536849975586 seconds
# Time between frames: 0.011652708053588867 seconds
# Time between frames: 0.010129451751708984 seconds
# Time between frames: 0.01069951057434082 seconds
# Time between frames: 0.009564399719238281 seconds
# Time between frames: 0.011536836624145508 seconds
# Time between frames: 0.009611845016479492 seconds
# Time between frames: 0.011376619338989258 seconds
# Time between frames: 0.009619474411010742 seconds
# Time between frames: 0.010696887969970703 seconds
# Time between frames: 0.009285926818847656 seconds
# Time between frames: 0.011706113815307617 seconds
# Time between frames: 0.01263880729675293 seconds
# Time between frames: 0.00884699821472168 seconds
# Time between frames: 0.009945869445800781 seconds
# Time between frames: 0.009676218032836914 seconds
# Time between frames: 0.009217262268066406 seconds
# Time between frames: 0.01079559326171875 seconds
# Time between frames: 0.009681463241577148 seconds
# Time between frames: 0.010895729064941406 seconds
# Time between frames: 0.009351491928100586 seconds
# Time between frames: 0.011414766311645508 seconds
# Time between frames: 0.009224414825439453 seconds
# Time between frames: 0.009593009948730469 seconds
# Time between frames: 0.010640144348144531 seconds
# Time between frames: 0.010770559310913086 seconds
# Time between frames: 0.009979486465454102 seconds
# Time between frames: 0.010503053665161133 seconds
# Time between frames: 0.010146856307983398 seconds
# Time between frames: 0.010579109191894531 seconds
# Time between frames: 0.01044011116027832 seconds
# Time between frames: 0.010861396789550781 seconds
# Time between frames: 0.009363889694213867 seconds
# Time between frames: 0.009006023406982422 seconds
# Time between frames: 0.011361360549926758 seconds
# Time between frames: 0.009403705596923828 seconds
# Time between frames: 0.011156320571899414 seconds
# Time between frames: 0.009787559509277344 seconds
# Time between frames: 0.011687994003295898 seconds
# Time between frames: 0.00917959213256836 seconds
# Time between frames: 0.01185917854309082 seconds
# Time between frames: 0.009486198425292969 seconds
# Time between frames: 0.010880470275878906 seconds
# Time between frames: 0.009480476379394531 seconds
# Time between frames: 0.01186370849609375 seconds
# Time between frames: 0.010325908660888672 seconds
# Time between frames: 0.010709762573242188 seconds
# Time between frames: 0.010382652282714844 seconds
# Time between frames: 0.009864568710327148 seconds
# Time between frames: 0.00909113883972168 seconds
# Time between frames: 0.011647939682006836 seconds
# Time between frames: 0.009510993957519531 seconds
# Time between frames: 0.010714530944824219 seconds
# Time between frames: 0.00980067253112793 seconds
# Time between frames: 0.012006282806396484 seconds
# Time between frames: 0.009335994720458984 seconds
# Time between frames: 0.01161050796508789 seconds
# Time between frames: 0.009482860565185547 seconds
# Time between frames: 0.009186029434204102 seconds
# Time between frames: 0.00973963737487793 seconds
# Time between frames: 0.011041879653930664 seconds
# Time between frames: 0.009824514389038086 seconds
# Time between frames: 0.00987863540649414 seconds
# Time between frames: 0.010529756546020508 seconds
# Time between frames: 0.010699033737182617 seconds
# Time between frames: 0.010266542434692383 seconds
# Time between frames: 0.010715246200561523 seconds
# Time between frames: 0.009928703308105469 seconds
# Time between frames: 0.0093536376953125 seconds
# Time between frames: 0.011252880096435547 seconds
# Time between frames: 0.009647846221923828 seconds
# Time between frames: 0.010658502578735352 seconds
# Time between frames: 0.009492874145507812 seconds
# Time between frames: 0.011747121810913086 seconds
# Time between frames: 0.009096145629882812 seconds
# Time between frames: 0.011159420013427734 seconds
# Time between frames: 0.0097198486328125 seconds
# Time between frames: 0.01081085205078125 seconds
# Time between frames: 0.009212255477905273 seconds
# Time between frames: 0.011032342910766602 seconds
# Time between frames: 0.010898590087890625 seconds
# Time between frames: 0.010759592056274414 seconds
# Time between frames: 0.009382963180541992 seconds
# Time between frames: 0.012021780014038086 seconds
# Time between frames: 0.009178400039672852 seconds
# Time between frames: 0.01117563247680664 seconds
# Time between frames: 0.009711980819702148 seconds
# Time between frames: 0.010710477828979492 seconds
# Time between frames: 0.009850263595581055 seconds
# Time between frames: 0.011640787124633789 seconds
# Time between frames: 0.009201765060424805 seconds
# Time between frames: 0.009399175643920898 seconds
# Time between frames: 0.009745121002197266 seconds
# Time between frames: 0.009559154510498047 seconds
# Time between frames: 0.010684728622436523 seconds
# Time between frames: 0.009551525115966797 seconds
# Time between frames: 0.011584758758544922 seconds
# Time between frames: 0.009001970291137695 seconds
# Time between frames: 0.011855602264404297 seconds
# Time between frames: 0.009748458862304688 seconds
# Time between frames: 0.011260032653808594 seconds
# Time between frames: 0.01029515266418457 seconds
# Time between frames: 0.010670900344848633 seconds
# Time between frames: 0.009716033935546875 seconds
# Time between frames: 0.011325597763061523 seconds
# Time between frames: 0.011411428451538086 seconds
# Time between frames: 0.009393453598022461 seconds
# Time between frames: 0.009618997573852539 seconds
# Time between frames: 0.011142730712890625 seconds
# Time between frames: 0.01321864128112793 seconds
# Time between frames: 0.009458780288696289 seconds
# Time between frames: 0.011322259902954102 seconds
# Time between frames: 0.009368181228637695 seconds
# Time between frames: 0.011419296264648438 seconds
# Time between frames: 0.009264230728149414 seconds
# Time between frames: 0.011945486068725586 seconds
# Time between frames: 0.009131908416748047 seconds
# Time between frames: 0.011245965957641602 seconds
# Time between frames: 0.00961446762084961 seconds
# Time between frames: 0.010862350463867188 seconds
# Time between frames: 0.009632587432861328 seconds
# Time between frames: 0.01205587387084961 seconds
# Time between frames: 0.00908350944519043 seconds
# Time between frames: 0.01132059097290039 seconds
# Time between frames: 0.010373830795288086 seconds
# Time between frames: 0.011557579040527344 seconds
# Time between frames: 0.010575294494628906 seconds
# Time between frames: 0.009995460510253906 seconds
# Time between frames: 0.01261591911315918 seconds
# Time between frames: 0.009302139282226562 seconds
# Time between frames: 0.012253761291503906 seconds
# Time between frames: 0.009226560592651367 seconds
# Time between frames: 0.009378194808959961 seconds
# Time between frames: 0.010597467422485352 seconds
# Time between frames: 0.012730836868286133 seconds
# Time between frames: 0.010066747665405273 seconds
# Time between frames: 0.011517524719238281 seconds
# Time between frames: 0.009288311004638672 seconds
# Time between frames: 0.010583162307739258 seconds
# Time between frames: 0.009307384490966797 seconds
# Time between frames: 0.011844396591186523 seconds
# Time between frames: 0.008989572525024414 seconds
# Time between frames: 0.011635303497314453 seconds
# Time between frames: 0.010084390640258789 seconds
# Time between frames: 0.011092424392700195 seconds
# Time between frames: 0.009683370590209961 seconds
# Time between frames: 0.011176347732543945 seconds
# Time between frames: 0.009144306182861328 seconds
# Time between frames: 0.011210441589355469 seconds
# Time between frames: 0.009407520294189453 seconds
# Time between frames: 0.011770248413085938 seconds
# Time between frames: 0.009171485900878906 seconds
# Time between frames: 0.011921167373657227 seconds
# Time between frames: 0.009227275848388672 seconds
# Time between frames: 0.011067390441894531 seconds
# Time between frames: 0.009271621704101562 seconds
# Time between frames: 0.010238170623779297 seconds
# Time between frames: 0.009079217910766602 seconds
# Time between frames: 0.008838176727294922 seconds
# Time between frames: 0.011747598648071289 seconds
# Time between frames: 0.009306907653808594 seconds
# Time between frames: 0.01123356819152832 seconds
# Time between frames: 0.00941610336303711 seconds
# Time between frames: 0.01156473159790039 seconds
# Time between frames: 0.009505748748779297 seconds
# Time between frames: 0.011630058288574219 seconds
# Time between frames: 0.009594202041625977 seconds
# Time between frames: 0.010505437850952148 seconds
# Time between frames: 0.009415626525878906 seconds
# Time between frames: 0.011833429336547852 seconds
# Time between frames: 0.008983850479125977 seconds
# Time between frames: 0.011445999145507812 seconds
# Time between frames: 0.009670734405517578 seconds
# Time between frames: 0.011185169219970703 seconds
# Time between frames: 0.009074687957763672 seconds
# Time between frames: 0.012257099151611328 seconds
# Time between frames: 0.010651826858520508 seconds
# Time between frames: 0.009873390197753906 seconds
# Time between frames: 0.009371280670166016 seconds
# Time between frames: 0.011965751647949219 seconds
# Time between frames: 0.009176254272460938 seconds
# Time between frames: 0.011286020278930664 seconds
# Time between frames: 0.00957345962524414 seconds
# Time between frames: 0.011446237564086914 seconds
# Time between frames: 0.010521173477172852 seconds
# Time between frames: 0.010383844375610352 seconds
# Time between frames: 0.008901834487915039 seconds
# Time between frames: 0.011722326278686523 seconds
# Time between frames: 0.009593963623046875 seconds
# Time between frames: 0.010896682739257812 seconds
# Time between frames: 0.009154081344604492 seconds
# Time between frames: 0.011890649795532227 seconds
# Time between frames: 0.00944066047668457 seconds
# Time between frames: 0.011237144470214844 seconds
# Time between frames: 0.009565591812133789 seconds
# Time between frames: 0.00978231430053711 seconds
# Time between frames: 0.00897836685180664 seconds
# Time between frames: 0.008913993835449219 seconds
# Time between frames: 0.011484861373901367 seconds
# Time between frames: 0.009230375289916992 seconds
# Time between frames: 0.011545181274414062 seconds
# Time between frames: 0.009717941284179688 seconds
# Time between frames: 0.011206388473510742 seconds
# Time between frames: 0.00949859619140625 seconds
# Time between frames: 0.011865854263305664 seconds
# Time between frames: 0.009471654891967773 seconds
# Time between frames: 0.010910987854003906 seconds
# Time between frames: 0.009469985961914062 seconds
# Time between frames: 0.011462688446044922 seconds
# Time between frames: 0.00903940200805664 seconds
# Time between frames: 0.011562347412109375 seconds
# Time between frames: 0.00956583023071289 seconds
# Time between frames: 0.011173248291015625 seconds
# Time between frames: 0.009351491928100586 seconds
# Time between frames: 0.011770963668823242 seconds
# Time between frames: 0.009204626083374023 seconds
# Time between frames: 0.011545658111572266 seconds
# Time between frames: 0.00980377197265625 seconds
# Time between frames: 0.011321544647216797 seconds
# Time between frames: 0.010083913803100586 seconds
# Time between frames: 0.010737419128417969 seconds
# Time between frames: 0.009328603744506836 seconds
# Time between frames: 0.011182069778442383 seconds
# Time between frames: 0.010369062423706055 seconds
# Time between frames: 0.010323047637939453 seconds
# Time between frames: 0.009455204010009766 seconds
# Time between frames: 0.011507749557495117 seconds
# Time between frames: 0.00962066650390625 seconds
# Time between frames: 0.011052608489990234 seconds
# Time between frames: 0.009053468704223633 seconds
# Time between frames: 0.011776447296142578 seconds
# Time between frames: 0.00915980339050293 seconds
# Time between frames: 0.01159048080444336 seconds
# Time between frames: 0.009993314743041992 seconds
# Time between frames: 0.010946989059448242 seconds
# Time between frames: 0.00903773307800293 seconds
# Time between frames: 0.011571407318115234 seconds
# Time between frames: 0.00921630859375 seconds
# Time between frames: 0.011165618896484375 seconds
# Time between frames: 0.009340047836303711 seconds
# Time between frames: 0.01190948486328125 seconds
# Time between frames: 0.009188175201416016 seconds
# Time between frames: 0.011838912963867188 seconds
# Time between frames: 0.009690999984741211 seconds
# Time between frames: 0.012020349502563477 seconds
# Time between frames: 0.009446382522583008 seconds
# Time between frames: 0.011126041412353516 seconds
# Time between frames: 0.009388208389282227 seconds
# Time between frames: 0.011555671691894531 seconds
# Time between frames: 0.01031184196472168 seconds
# Time between frames: 0.01050567626953125 seconds
# Time between frames: 0.009343624114990234 seconds
# Time between frames: 0.01150202751159668 seconds
# Time between frames: 0.009315252304077148 seconds
# Time between frames: 0.011052846908569336 seconds
# Time between frames: 0.010046243667602539 seconds
# Time between frames: 0.011515378952026367 seconds
# Time between frames: 0.009348869323730469 seconds
# Time between frames: 0.011269330978393555 seconds
# Time between frames: 0.009537458419799805 seconds
# Time between frames: 0.011348962783813477 seconds
# Time between frames: 0.009824752807617188 seconds
# Time between frames: 0.011033058166503906 seconds
# Time between frames: 0.00983738899230957 seconds
# Time between frames: 0.011624574661254883 seconds
# Time between frames: 0.009931564331054688 seconds
# Time between frames: 0.009921550750732422 seconds
# Time between frames: 0.009428262710571289 seconds
# Time between frames: 0.01149892807006836 seconds
# Time between frames: 0.009412288665771484 seconds
# Time between frames: 0.011350631713867188 seconds
# Time between frames: 0.010019540786743164 seconds
# Time between frames: 0.009914636611938477 seconds
# Time between frames: 0.009373188018798828 seconds
# Time between frames: 0.012418270111083984 seconds
# Time between frames: 0.009613513946533203 seconds
# Time between frames: 0.011375188827514648 seconds
# Time between frames: 0.009233951568603516 seconds
# Time between frames: 0.011871099472045898 seconds
# Time between frames: 0.009575843811035156 seconds
# Time between frames: 0.011575698852539062 seconds
# Time between frames: 0.012722015380859375 seconds
# Time between frames: 0.009371519088745117 seconds
# Time between frames: 0.012195587158203125 seconds
# Time between frames: 0.010215044021606445 seconds
# Time between frames: 0.010514974594116211 seconds
# Time between frames: 0.009417057037353516 seconds
# Time between frames: 0.011701107025146484 seconds
# Time between frames: 0.009221792221069336 seconds
# Time between frames: 0.011224985122680664 seconds
# Time between frames: 0.010011911392211914 seconds
# Time between frames: 0.011581182479858398 seconds
# Time between frames: 0.009654998779296875 seconds
# Time between frames: 0.010606765747070312 seconds
# Time between frames: 0.01024627685546875 seconds
# Time between frames: 0.010306119918823242 seconds
# Time between frames: 0.009732961654663086 seconds
# Time between frames: 0.011513710021972656 seconds
# Time between frames: 0.009147882461547852 seconds
# Time between frames: 0.011695146560668945 seconds
# Time between frames: 0.00970149040222168 seconds
# Time between frames: 0.010735273361206055 seconds
# Time between frames: 0.009181737899780273 seconds
# Time between frames: 0.011869192123413086 seconds
# Time between frames: 0.00980067253112793 seconds
# Time between frames: 0.011251211166381836 seconds
# Time between frames: 0.00991058349609375 seconds
# Time between frames: 0.011085987091064453 seconds
# Time between frames: 0.009514808654785156 seconds
# Time between frames: 0.011565923690795898 seconds
# Time between frames: 0.010529041290283203 seconds
# Time between frames: 0.009597539901733398 seconds
# Time between frames: 0.01004338264465332 seconds
# Time between frames: 0.011083126068115234 seconds
# Time between frames: 0.009462118148803711 seconds
# Time between frames: 0.011610984802246094 seconds
# Time between frames: 0.009417295455932617 seconds
# Time between frames: 0.011182308197021484 seconds
# Time between frames: 0.009732961654663086 seconds
# Time between frames: 0.01166391372680664 seconds
# Time between frames: 0.009511470794677734 seconds
# Time between frames: 0.010106086730957031 seconds
# Time between frames: 0.010361433029174805 seconds
# Time between frames: 0.011458396911621094 seconds
# Time between frames: 0.01005864143371582 seconds
# Time between frames: 0.010163068771362305 seconds
# Time between frames: 0.010006904602050781 seconds
# Time between frames: 0.010531425476074219 seconds
# Time between frames: 0.010598182678222656 seconds
# Time between frames: 0.010462284088134766 seconds
# Time between frames: 0.00979304313659668 seconds
# Time between frames: 0.01158905029296875 seconds
# Time between frames: 0.009826183319091797 seconds
# Time between frames: 0.00997304916381836 seconds
# Time between frames: 0.009273052215576172 seconds
# Time between frames: 0.011948347091674805 seconds
# Time between frames: 0.009801626205444336 seconds
# Time between frames: 0.011754989624023438 seconds
# Time between frames: 0.010375499725341797 seconds
# Time between frames: 0.011816263198852539 seconds
# Time between frames: 0.012004375457763672 seconds
# Time between frames: 0.010528326034545898 seconds
# Time between frames: 0.011388301849365234 seconds
# Time between frames: 0.012494564056396484 seconds

# %% [markdown]
# ## Test generate branch by stochastic policy neural network

# %%
key = jax.random.key(1234)
memory_settings = Memory_settings(50000, 4, 1, 1)
exp_pool = None

# %%
# Let's generate some observations and rewards

def reshape_data(datas, batch_size, fock_size):
    def fn(data):
        new_shape = [*(data.shape)][1:]
        new_shape[0]=batch_size*fock_size
        # print(new_shape)
        return data.reshape(new_shape)
    return jax.tree.map(fn,datas)



init_batch_size = 10
batch_size = init_batch_size
fock_size = 10

# Start with the fixed init state
keys = jax.random.split(key, batch_size)
datas = reset(mjx_model,batch_size)


# print(datas.qpos)
for i in range(10):    # For 2 seconds
    datas, keys, exp = jit_v_nn_multi_steps(controller_params, mjx_model, datas, keys)
    # print(datas.qvel.shape, datas.ten_J.shape)
    if(i == 2):    # After 0.5 seconds fock the simulation
        keys = jax.vmap(jax.random.split, in_axes=(0,None))(keys, fock_size)
        datas, keys, exp = jit_vv_nn_multi_steps(controller_params, mjx_model, datas, keys)
        keys = keys.reshape(batch_size*fock_size)
        datas = reshape_data(datas, batch_size, fock_size)
        exp = reshape_data(exp, batch_size, fock_size)
        # print(datas.qvel.shape, datas.ten_J.shape)
        batch_size = batch_size*fock_size
    exp_pool = Memory.add_exp(memory_settings, exp_pool, exp)

# %%
import matplotlib.pyplot as plt
# print(exp_pool)
print(exp_pool.states.shape)
key = jax.random.split(key, 1)[0]
batch = Memory.sample(exp_pool, 100, key)
key = jax.random.split(key, 1)[0]
print(batch.states[:,0:2].shape)
print(datas.qpos.shape)
plt.plot(exp_pool.states.T[1])
plt.plot(exp_pool.rewards)
# Out:
# (50000, 4)
# (100, 2)
# (100, 2)

# %% [markdown]
# ## Train the critic neural network with generated data

# %%
import flax.linen


v_critic = jax.vmap(critic.apply,in_axes=(None, 0))


def critic_loss(params, batch):
    discount = 0.95
    states = batch.states
    next_states = batch.next_states
    actions = batch.actions
    rewards = batch.rewards
    
    critic_score = v_critic(params, states)
    target = rewards + discount* critic.apply(params, next_states)
    
    loss = optax.l2_loss(critic_score, target)
    loss = jp.mean(loss)
    return loss
    
jit_critic_loss_value = jax.jit(jax.value_and_grad(critic_loss))

# %%
# Reset Critic_NN parameters
critic_params = critic.init(key, jp.empty([1,mjx_model.nq*2]))
tx = optax.adam(learning_rate=0.00002)
opt_state = tx.init(critic_params)
jit_tx_update = jax.jit(tx.update)
jit_apply_update = jax.jit(optax.apply_updates)

# %%
for i in range(2000):
    batch = Memory.sample(exp_pool, 40, key)
    key = jax.random.split(key, 1)[0]
    loss, loss_grad = jit_critic_loss_value(critic_params, batch)
    print(loss)
    # Update params
    updates, opt_stats = jit_tx_update(loss_grad, opt_state)
    critic_params = jit_apply_update(critic_params, updates)
# Out:
# 5.2059006e-09
# 7.253749e-09
# 2.3176217e-08
# 1.5949361e-08
# 6.981329e-09
# 1.3357202e-08
# 6.84129e-09
# 5.5467178e-09
# 7.540989e-09
# 7.73889e-09
# 1.8783886e-08
# 5.8320295e-09
# 7.12424e-09
# 1.3012751e-08
# 1.0151804e-08
# 8.943726e-09
# 6.1252963e-09
# 9.607688e-09
# 2.3886978e-08
# 1.5255484e-08
# 1.6464327e-08
# 1.5520445e-08
# 7.687945e-09
# 9.271721e-09
# 6.935655e-09
# 1.345419e-08
# 1.7835088e-08
# 1.2427319e-08
# 7.1372357e-09
# 1.093436e-08
# 1.7973647e-08
# 4.1984705e-09
# 1.769264e-08
# 9.120298e-09
# 1.08579625e-08
# 5.487157e-09
# 8.1215505e-09
# 7.2664648e-09
# 1.0149636e-08
# 1.2401671e-08
# 1.2569127e-08
# 5.7033094e-09
# 1.8973637e-08
# 1.0258041e-08
# 1.1356746e-08
# 9.589999e-09
# 5.68514e-09
# 1.08339675e-08
# 1.1099821e-08
# 1.40922465e-08
# 1.3758532e-08
# 1.5077122e-08
# 1.4482197e-08
# 9.2193355e-09
# 8.849947e-09
# 8.213735e-09
# 1.2508678e-08
# 8.730574e-09
# 5.033643e-09
# 1.2547488e-08
# 5.0198965e-09
# 1.206178e-08
# 1.1397711e-08
# 8.137221e-09
# 1.5522138e-08
# 7.653486e-09
# 4.888315e-09
# 5.928443e-09
# 7.191932e-09
# 6.8255988e-09
# 1.3573836e-08
# 5.5058536e-09
# 8.88367e-09
# 1.3183441e-08
# 1.1154415e-08
# 5.1359517e-09
# 7.44609e-09
# 7.782201e-09
# 1.1096561e-08
# 1.6574225e-08
# 6.5235684e-09
# 1.0113455e-08
# 8.44718e-09
# 8.742137e-09
# 8.28361e-09
# 1.35742315e-08
# 9.795673e-09
# 1.2880213e-08
# 1.4945261e-08
# 2.3346047e-08
# 1.4438361e-08
# 7.041863e-09
# 5.5294307e-09
# 8.79609e-09
# 4.4060973e-09
# 1.43009675e-08
# 1.0194138e-08
# 1.9861012e-08
# 1.3106805e-08
# 9.043821e-09
# 2.1628273e-08
# 4.915359e-09
# 6.768404e-09
# 2.2349928e-08
# 9.415316e-09
# 6.5446444e-09
# 9.266438e-09
# 6.6647674e-09
# 5.6519798e-09
# 1.2975145e-08
# 6.4712853e-09
# 8.081886e-09
# 2.3844214e-08
# 5.663953e-09
# 2.044593e-08
# 5.57765e-09
# 1.5821476e-08
# 8.672427e-09
# 1.1835733e-08
# 8.109073e-09
# 1.04344124e-08
# 4.4280926e-09
# 5.167898e-09
# 1.059086e-08
# 2.5449763e-08
# 1.2121515e-08
# 3.4383187e-09
# 9.534088e-09
# 1.8578005e-08
# 7.870857e-09
# 1.8017912e-08
# 8.013968e-09
# 1.0229576e-08
# 9.456031e-09
# 5.6944827e-09
# 6.7597563e-09
# 1.6578133e-08
# 1.1093683e-08
# 9.965085e-09
# 8.044643e-09
# 9.474224e-09
# 1.4704935e-08
# 7.662406e-09
# 8.376781e-09
# 1.3057546e-08
# 1.2379441e-08
# 1.2383235e-08
# 6.9784067e-09
# 6.176512e-09
# 4.4852353e-09
# 1.1702876e-08
# 1.2662382e-08
# 4.2227395e-09
# 1.6568874e-08
# 7.3142425e-09
# 9.137371e-09
# 1.35582e-08
# 1.2976551e-08
# 8.177781e-09
# 7.918913e-09
# 9.712294e-09
# 1.582036e-08
# 7.078076e-09
# 1.3041351e-08
# 9.571451e-09
# 8.182761e-09
# 1.2718336e-08
# 8.184019e-09
# 8.256011e-09
# 1.26367015e-08
# 9.2755e-09
# 8.425924e-09
# 1.1923923e-08
# 9.032087e-09
# 6.3187864e-09
# 1.1689269e-08
# 1.5875631e-08
# 1.234136e-08
# 1.8530349e-08
# 6.887619e-09
# 8.260649e-09
# 9.640679e-09
# 2.2148571e-08
# 8.7670164e-09
# 9.99845e-09
# 1.2871118e-08
# 8.563229e-09
# 8.139115e-09
# 2.1540604e-08
# 1.7259396e-08
# 1.0025558e-08
# 5.587649e-09
# 2.2252658e-08
# 1.5641906e-08
# 1.175135e-08
# 6.102194e-09
# 5.5581837e-09
# 6.6139636e-09
# 6.521606e-09
# 8.2218135e-09
# 6.4927086e-09
# 1.3602056e-08
# 1.691798e-08
# 1.2062647e-08
# 4.440489e-09
# 1.07518785e-08
# 1.7211443e-08
# 6.9284596e-09
# 1.05542375e-08
# 1.048516e-08
# 9.181339e-09
# 9.419527e-09
# 2.8545367e-08
# 3.9906705e-09
# 3.999233e-09
# 5.164234e-09
# 6.3989747e-09
# 1.14145795e-08
# 1.8251058e-08
# 7.624059e-09
# 9.85897e-09
# 2.856889e-08
# 8.095907e-09
# 6.4046946e-09
# 8.547647e-09
# 1.0541209e-08
# 1.6255294e-08
# 1.1211316e-08
# 1.3812712e-08
# 4.357819e-09
# 9.878251e-09
# 7.531506e-09
# 1.115715e-08
# 9.469804e-09
# 7.451599e-09
# 7.451547e-09
# 1.4450072e-08
# 6.422461e-09
# 1.1417389e-08
# 9.412519e-09
# 4.602707e-09
# 1.1158232e-08
# 1.33418965e-08
# 6.4987633e-09
# 1.2420222e-08
# 1.1639564e-08
# 1.363373e-08
# 1.1329221e-08
# 8.045514e-09
# 1.3256726e-08
# 7.974643e-09
# 1.1751757e-08
# 1.0798028e-08
# 1.13636585e-08
# 1.1506734e-08
# 1.8137875e-08
# 8.7372785e-09
# 2.168132e-08
# 1.6562892e-08
# 3.8128363e-09
# 4.0415933e-09
# 2.7273272e-08
# 1.0877834e-08
# 1.9156316e-08
# 9.13255e-09
# 9.692568e-09
# 3.360678e-08
# 1.5905849e-08
# 2.9098471e-08
# 1.649745e-08
# 1.0124153e-08
# 8.246636e-09
# 1.1864467e-08
# 3.187733e-08
# 1.2543488e-08
# 1.18177965e-08
# 6.4560624e-09
# 6.123638e-09
# 1.5717744e-08
# 1.6254054e-08
# 4.9339413e-09
# 1.1304045e-08
# 8.277101e-09
# 2.4883326e-08
# 1.0587273e-08
# 1.4651405e-08
# 1.7104352e-08
# 1.0674839e-08
# 9.718636e-09
# 7.65053e-09
# 9.586784e-09
# 1.8982352e-08
# 1.1763961e-08
# 8.094932e-09
# 1.3614164e-08
# 2.8588465e-08
# 2.1244444e-08
# 5.7203215e-09
# 8.096087e-09
# 2.0016188e-08
# 1.123789e-08
# 5.6399942e-09
# 4.4609387e-09
# 7.672583e-09
# 1.73494e-08
# 5.3577627e-09
# 1.2913742e-08
# 6.548303e-09
# 3.6473832e-08
# 6.704455e-09
# 5.785368e-09
# 1.4594578e-08
# 7.1933086e-09
# 9.72493e-09
# 9.645179e-09
# 4.760076e-09
# 6.2033805e-09
# 6.230813e-09
# 4.5670308e-09
# 1.0298516e-08
# 7.5397635e-09
# 9.659452e-09
# 9.677024e-09
# 1.4252492e-08
# 1.5244177e-08
# 9.232652e-09
# 7.0021193e-09
# 1.9189404e-08
# 1.3235047e-08
# 6.0432335e-09
# 1.7059094e-08
# 1.1039272e-08
# 1.3072858e-08
# 7.610921e-09
# 1.429669e-08
# 1.3598873e-08
# 1.297164e-08
# 1.0363981e-08
# 5.636129e-09
# 1.4549897e-08
# 1.0661205e-08
# 1.8203082e-08
# 6.3407017e-09
# 1.333678e-08
# 5.621112e-09
# 1.08104805e-08
# 7.919188e-09
# 5.375124e-09
# 3.67412e-08
# 4.4579815e-09
# 5.7844747e-09
# 1.1266957e-08
# 9.342066e-09
# 1.1176425e-08
# 4.783609e-09
# 6.8627815e-09
# 1.557748e-08
# 1.24105926e-08
# 7.2426647e-09
# 1.6469944e-08
# 1.437962e-08
# 8.044168e-09
# 2.4472113e-08
# 7.027754e-09
# 1.0433585e-08
# 1.2133668e-08
# 4.5619473e-09
# 2.4080107e-08
# 1.0001709e-08
# 7.750594e-09
# 6.61984e-09
# 1.6491407e-08
# 1.3856479e-08
# 1.6551956e-08
# 6.7823556e-09
# 7.454843e-09
# 6.9020842e-09
# 1.2277941e-08
# 1.5942312e-08
# 1.1725915e-08
# 8.312214e-09
# 1.6825016e-08
# 5.0386166e-09
# 1.0643921e-08
# 1.2495285e-08
# 1.45421835e-08
# 1.3458122e-08
# 1.2344005e-08
# 6.153112e-09
# 1.4880953e-08
# 1.5741898e-08
# 6.2529346e-09
# 8.205015e-09
# 1.1154e-08
# 1.6560202e-08
# 2.4365756e-08
# 1.1818197e-08
# 1.8364318e-08
# 1.2847241e-08
# 1.1452012e-08
# 7.994161e-09
# 1.1256726e-08
# 1.2866853e-08
# 1.0694678e-08
# 1.81155e-08
# 1.2702116e-08
# 8.16422e-09
# 1.098293e-08
# 9.342948e-09
# 7.554556e-09
# 1.823572e-08
# 1.019577e-08
# 6.287262e-09
# 8.022858e-09
# 3.722766e-08
# 5.715722e-09
# 1.9559385e-08
# 5.366214e-09
# 1.165226e-08
# 9.819985e-09
# 1.4883748e-08
# 1.7235655e-08
# 1.11838885e-08
# 6.2044783e-09
# 1.8080351e-08
# 3.592388e-09
# 1.4073788e-08
# 1.0135567e-08
# 1.3665846e-08
# 1.4509232e-08
# 8.043262e-09
# 1.8205702e-08
# 9.46108e-09
# 2.2150493e-08
# 6.330366e-09
# 2.3889285e-08
# 1.2978915e-08
# 6.3740027e-09
# 9.56309e-09
# 1.3922994e-08
# 1.14040555e-08
# 8.064641e-09
# 1.3409464e-08
# 8.003145e-09
# 1.0525515e-08
# 9.623608e-09
# 2.2586931e-08
# 1.4842008e-08
# 8.9842365e-09
# 5.549525e-09
# 8.402502e-09
# 2.3553673e-08
# 1.9821082e-08
# 7.5093345e-09
# 1.9695733e-08
# 8.040404e-09
# 1.1493414e-08
# 1.2107401e-08
# 2.0722549e-08
# 1.1843691e-08
# 4.117021e-09
# 5.881519e-09
# 6.222432e-09
# 1.1329976e-08
# 1.792653e-08
# 1.188119e-08
# 1.128843e-08
# 9.686889e-09
# 1.2865172e-08
# 8.246319e-09
# 1.2285757e-08
# 8.847468e-09
# 1.0898247e-08
# 1.3416043e-08
# 5.0023026e-09
# 7.1744624e-09
# 1.9108525e-08
# 2.0879998e-08
# 7.1741946e-09
# 6.1412373e-09
# 1.5434557e-08
# 9.730397e-09
# 9.9133155e-09
# 2.1425292e-08
# 8.040364e-09
# 8.424631e-09
# 5.8408776e-09
# 1.43613e-08
# 7.601251e-09
# 5.8943477e-09
# 6.3942496e-09
# 5.4556524e-09
# 1.5753287e-08
# 7.720958e-09
# 7.2058874e-09
# 1.218513e-08
# 7.191429e-09
# 5.9533014e-09
# 1.6989707e-08
# 3.279891e-08
# 1.7715633e-08
# 1.0884001e-08
# 7.684631e-09
# 1.37266625e-08
# 6.408947e-09
# 5.277428e-09
# 1.3193841e-08
# 1.0475371e-08
# 6.152541e-09
# 7.951807e-09
# 1.5257944e-08
# 1.7951589e-08
# 1.710188e-08
# 5.3966573e-09
# 2.15852e-08
# 1.34116025e-08
# 1.0746386e-08
# 1.33501175e-08
# 1.6659351e-08
# 1.5999289e-08
# 6.351674e-09
# 9.357399e-09
# 1.1926521e-08
# 1.0767934e-08
# 2.1727372e-08
# 6.808635e-09
# 1.42545336e-08
# 5.5054565e-09
# 8.978164e-09
# 1.2369273e-08
# 8.379369e-09
# 1.2723748e-08
# 6.83285e-09
# 5.2824625e-09
# 2.153126e-08
# 1.30208235e-08
# 8.045046e-09
# 1.3041997e-08
# 7.550137e-09
# 9.596237e-09
# 7.490025e-09
# 8.512478e-09
# 1.1200919e-08
# 1.2930366e-08
# 9.263406e-09
# 1.2993303e-08
# 6.9788557e-09
# 7.766533e-09
# 9.944171e-09
# 6.425762e-09
# 6.567099e-09
# 1.1272933e-08
# 5.987495e-09
# 9.928872e-09
# 1.2071015e-08
# 1.3777691e-08
# 8.825242e-09
# 7.3143442e-09
# 1.0753114e-08
# 5.585319e-09
# 1.1054561e-08
# 1.17816645e-08
# 7.80496e-09
# 3.470998e-08
# 7.658434e-09
# 1.5807405e-08
# 3.5762235e-09
# 1.1420848e-08
# 7.930351e-09
# 6.2496084e-09
# 6.6421735e-09
# 9.399175e-09
# 7.7661175e-09
# 7.2911166e-09
# 1.6855553e-08
# 2.3677378e-08
# 5.2856715e-09
# 9.286608e-09
# 2.0030255e-08
# 8.366885e-09
# 1.1744435e-08
# 1.5150858e-08
# 2.703292e-08
# 1.0027005e-08
# 7.021967e-09
# 6.8289325e-09
# 8.9437595e-09
# 9.049551e-09
# 5.9693046e-09
# 5.0217763e-09
# 4.285066e-09
# 5.477576e-09
# 1.0391227e-08
# 1.5321467e-08
# 3.6431004e-08
# 7.4044446e-09
# 7.6719315e-09
# 1.3018807e-08
# 8.834889e-09
# 5.781758e-09
# 1.0425334e-08
# 7.668761e-09
# 1.5094816e-08
# 7.298355e-09
# 1.1831243e-08
# 7.314823e-09
# 1.2546012e-08
# 5.7890044e-09
# 6.06369e-09
# 6.8330595e-09
# 1.6613283e-08
# 8.469364e-09
# 2.2170193e-08
# 2.4924464e-08
# 1.635414e-08
# 2.4302834e-08
# 4.7598654e-09
# 9.305842e-09
# 1.2627888e-08
# 8.266892e-09
# 1.2037716e-08
# 1.7602662e-08
# 1.296519e-08
# 1.30707605e-08
# 6.619564e-09
# 1.14091225e-08
# 3.5632302e-09
# 1.099604e-08
# 2.1797925e-08
# 1.1958306e-08
# 1.1819849e-08
# 6.453478e-09
# 1.9689416e-08
# 1.1397939e-08
# 8.3444345e-09
# 2.4493975e-08
# 4.31915e-09
# 1.3277179e-08
# 6.258015e-09
# 6.772295e-09
# 1.9508434e-08
# 1.01526005e-08
# 2.0860643e-08
# 8.260538e-09
# 6.586865e-09
# 1.3826752e-08
# 7.10853e-09
# 7.396257e-09
# 1.1449873e-08
# 7.437831e-09
# 8.171293e-09
# 6.2238357e-09
# 6.1346137e-09
# 1.30872255e-08
# 1.3740709e-08
# 5.5733738e-09
# 1.2310532e-08
# 1.04172235e-08
# 4.7896243e-09
# 1.1453978e-08
# 1.4513479e-08
# 1.7636507e-08
# 2.4677309e-08
# 3.913048e-09
# 8.819572e-09
# 5.9150973e-09
# 1.977383e-08
# 1.0159707e-08
# 1.0823375e-08
# 6.310819e-09
# 1.7058417e-08
# 1.3898182e-08
# 5.2399574e-09
# 1.01446025e-08
# 4.841682e-09
# 1.2800763e-08
# 1.3563914e-08
# 1.062704e-08
# 1.16112115e-08
# 1.49937e-08
# 6.9973782e-09
# 7.511971e-09
# 2.5158021e-08
# 7.706126e-09
# 1.1140849e-08
# 5.9536482e-09
# 1.4899058e-08
# 4.8164437e-09
# 1.0455288e-08
# 1.2308511e-08
# 8.668275e-09
# 1.0389846e-08
# 7.6639255e-09
# 1.5315075e-08
# 1.2973118e-08
# 2.0572848e-08
# 2.3232179e-08
# 1.914938e-08
# 9.90575e-09
# 1.8084211e-08
# 4.571821e-09
# 7.2376665e-09
# 9.651958e-09
# 9.85576e-09
# 1.0893659e-08
# 1.7223567e-08
# 6.0559984e-09
# 1.9192374e-08
# 5.221436e-09
# 1.1846781e-08
# 6.754791e-09
# 6.2082406e-09
# 5.6320375e-09
# 1.9685775e-08
# 2.8423475e-08
# 1.0401326e-08
# 9.906754e-09
# 1.6496942e-08
# 8.094239e-09
# 9.150705e-09
# 5.808228e-09
# 1.7305135e-08
# 5.087683e-09
# 8.612509e-09
# 7.600381e-09
# 1.3952826e-08
# 7.973654e-09
# 6.0177934e-09
# 8.9567695e-09
# 1.0581478e-08
# 7.2907027e-09
# 1.0653374e-08
# 1.4096358e-08
# 9.298149e-09
# 8.173266e-09
# 5.705464e-09
# 4.9277924e-09
# 1.4328586e-08
# 1.443659e-08
# 1.5826565e-08
# 9.252186e-09
# 7.939721e-09
# 5.8067755e-09
# 1.4270024e-08
# 1.4438783e-08
# 7.6286035e-09
# 9.696184e-09
# 2.1042126e-08
# 6.271965e-09
# 4.8988005e-09
# 6.5534778e-09
# 2.2600132e-08
# 6.3109185e-09
# 1.36697995e-08
# 9.803053e-09
# 7.3740525e-09
# 5.6198597e-09
# 1.1115226e-08
# 1.03987565e-08
# 7.835055e-09
# 4.1959196e-09
# 1.889269e-08
# 1.2011064e-08
# 9.259529e-09
# 1.1777435e-08
# 7.462012e-09
# 1.1338357e-08
# 1.0326095e-08
# 1.2136707e-08
# 4.814269e-08
# 1.7795468e-08
# 1.950866e-08
# 9.537517e-09
# 6.7352866e-09
# 1.5547448e-08
# 1.8767475e-08
# 9.7474375e-09
# 6.6801333e-09
# 4.6360977e-09
# 1.1401055e-08
# 1.6709436e-08
# 5.231573e-09
# 4.658526e-09
# 9.240023e-09
# 6.9414563e-09
# 8.272024e-09
# 6.4260597e-09
# 1.0629651e-08
# 1.4579863e-08
# 1.0353309e-08
# 9.549722e-09
# 4.3621007e-08
# 2.0427176e-08
# 1.1355877e-08
# 1.7034685e-08
# 2.7580308e-08
# 1.0659547e-08
# 8.174942e-09
# 1.0792802e-08
# 5.3979075e-09
# 1.0006022e-08
# 1.7246217e-08
# 1.3458385e-08
# 1.1718977e-08
# 1.1968547e-08
# 2.02631e-08
# 8.69111e-09
# 9.245776e-09
# 7.567137e-09
# 1.0034542e-08
# 1.0882115e-08
# 1.6257786e-08
# 8.288329e-09
# 8.779312e-09
# 4.9741025e-09
# 1.7189327e-08
# 7.2550748e-09
# 1.7387839e-08
# 9.211601e-09
# 4.110318e-09
# 1.0691518e-08
# 4.6721733e-09
# 1.5176713e-08
# 8.663928e-09
# 8.942783e-09
# 2.6511094e-08
# 4.7063415e-09
# 7.938624e-09
# 9.979564e-09
# 5.5429092e-09
# 9.344083e-09
# 7.997892e-09
# 1.2861586e-08
# 1.2895244e-08
# 1.8863103e-08
# 6.9116015e-09
# 1.9089876e-08
# 8.400845e-09
# 9.515583e-09
# 1.2237819e-08
# 1.3920661e-08
# 1.297047e-08
# 1.0823378e-08
# 1.2020706e-08
# 2.5784914e-08
# 8.8238865e-09
# 1.4795453e-08
# 3.875438e-09
# 1.1084164e-08
# 7.595422e-09
# 1.1912284e-08
# 1.3293856e-08
# 1.3079388e-08
# 2.4551033e-08
# 9.4854995e-09
# 7.2874715e-09
# 1.275957e-08
# 7.818935e-09
# 1.591134e-08
# 8.969087e-09
# 5.172619e-09
# 8.546318e-09
# 1.1151687e-08
# 2.238005e-08
# 2.2931912e-08
# 9.324673e-09
# 1.9356909e-08
# 5.84538e-09
# 6.233538e-09
# 2.2014783e-08
# 1.958726e-08
# 8.199971e-09
# 1.2417213e-08
# 5.748364e-09
# 1.4835556e-08
# 6.9457684e-09
# 1.5479106e-08
# 1.0718062e-08
# 1.1630087e-08
# 1.1568688e-08
# 5.358739e-09
# 3.5701692e-08
# 6.647713e-09
# 1.18832135e-08
# 7.0942576e-09
# 7.992088e-09
# 1.0644779e-08
# 1.2432792e-08
# 7.872437e-09
# 1.7865288e-08
# 8.087283e-09
# 1.06448095e-08
# 1.0621849e-08
# 5.1589826e-09
# 7.656173e-09
# 5.9364504e-09
# 2.1557103e-08
# 6.713276e-09
# 1.7158932e-08
# 1.088993e-08
# 7.538192e-09
# 1.133916e-08
# 1.1498886e-08
# 9.39708e-09
# 6.0496106e-09
# 3.5031096e-08
# 1.1423134e-08
# 5.9313874e-09
# 5.090675e-09
# 1.3898019e-08
# 1.0544072e-08
# 9.721029e-09
# 6.302213e-09
# 9.460469e-09
# 5.6931704e-09
# 5.089047e-09
# 1.4322377e-08
# 3.057854e-08
# 1.1753079e-08
# 1.0669075e-08
# 1.046179e-08
# 7.568457e-09
# 8.490626e-09
# 5.384829e-09
# 1.728121e-08
# 6.36172e-09
# 8.890258e-09
# 9.897647e-09
# 2.0028208e-08
# 5.343423e-09
# 1.3890793e-08
# 8.324213e-09
# 9.398014e-09
# 1.5895656e-08
# 1.2292211e-08
# 4.2807815e-09
# 2.0284707e-08
# 1.2242151e-08
# 4.9091993e-09
# 1.1971683e-08
# 5.7341936e-09
# 6.9042074e-09
# 5.326003e-09
# 1.1311076e-08
# 1.2154946e-08
# 1.2977657e-08
# 1.3536199e-08
# 6.1223533e-09
# 1.2334325e-08
# 5.835248e-09
# 1.2976348e-08
# 1.4966792e-08
# 9.971754e-09
# 8.366103e-09
# 8.6189e-09
# 9.3475405e-09
# 4.1199293e-09
# 1.32880364e-08
# 1.5844298e-08
# 6.6730714e-09
# 7.7031235e-09
# 2.8542397e-08
# 1.3000305e-08
# 1.1062144e-08
# 9.078576e-09
# 1.8574147e-08
# 1.4447832e-08
# 5.7362186e-09
# 2.6253193e-08
# 7.3040627e-09
# 1.3565132e-08
# 1.1954424e-08
# 8.409102e-09
# 6.86103e-09
# 8.1546565e-09
# 1.0262035e-08
# 5.385396e-09
# 1.4864151e-08
# 1.1223321e-08
# 8.803158e-09
# 1.2072514e-08
# 1.7455154e-08
# 8.793141e-09
# 1.3110757e-08
# 8.744064e-09
# 6.9811605e-09
# 6.064077e-09
# 1.1109939e-08
# 3.766319e-09
# 1.3344954e-08
# 8.83063e-09
# 9.0487395e-09
# 1.7229132e-08
# 1.9643991e-08
# 1.4693947e-08
# 7.5482465e-09
# 1.4281016e-08
# 7.2109465e-09
# 7.2257644e-09
# 1.03693205e-08
# 8.042133e-09
# 9.524249e-09
# 1.9041037e-08
# 7.205134e-09
# 6.042928e-09
# 1.946286e-08
# 1.3688918e-08
# 1.0187903e-08
# 7.593161e-09
# 1.2774095e-08
# 9.986945e-09
# 7.739371e-09
# 1.3576536e-08
# 5.7208083e-09
# 1.8731345e-08
# 1.2099045e-08
# 1.6109807e-08
# 5.1627267e-09
# 2.6109793e-08
# 1.0306464e-08
# 9.337545e-09
# 9.675183e-09
# 2.0148773e-08
# 9.134561e-09
# 9.410406e-09
# 8.669891e-09
# 6.8620234e-09
# 7.673271e-09
# 5.022219e-09
# 6.6913315e-09
# 7.755186e-09
# 9.640411e-09
# 4.1323007e-09
# 1.7458133e-08
# 8.328279e-09
# 1.7025945e-08
# 6.9197093e-09
# 6.4729373e-09
# 5.4707363e-09
# 4.8212025e-09
# 1.8305334e-08
# 5.2225446e-09
# 9.4328625e-09
# 1.7313127e-08
# 1.756853e-08
# 5.445331e-09
# 1.4578363e-08
# 9.257916e-09
# 2.2110328e-08
# 5.780536e-09
# 1.1487034e-08
# 1.0906023e-08
# 1.1805842e-08
# 7.335456e-09
# 1.2622739e-08
# 1.1017794e-08
# 1.3147593e-08
# 5.985755e-09
# 1.2933389e-08
# 1.0878582e-08
# 1.3232028e-08
# 1.7494882e-08
# 8.86425e-09
# 1.295127e-08
# 1.0839592e-08
# 6.8375385e-09
# 1.2899789e-08
# 1.3843675e-08
# 1.2249686e-08
# 9.900957e-09
# 1.1798311e-08
# 9.602199e-09
# 8.202403e-09
# 2.3874216e-08
# 1.1383565e-08
# 4.093651e-09
# 1.1124718e-08
# 9.667261e-09
# 1.1033289e-08
# 1.21251125e-08
# 4.1544306e-09
# 3.774738e-08
# 5.075087e-09
# 1.6290171e-08
# 2.1977497e-08
# 7.680987e-09
# 1.4073095e-08
# 1.4602762e-08
# 7.990339e-09
# 1.369182e-08
# 1.3038042e-08
# 7.031463e-09
# 1.2578897e-08
# 9.478074e-09
# 1.8583748e-08
# 6.961431e-09
# 1.4219916e-08
# 8.5468566e-09
# 7.4162076e-09
# 2.943156e-08
# 1.1563407e-08
# 1.9258623e-08
# 5.6994622e-09
# 1.05953495e-08
# 9.7841335e-09
# 9.76566e-09
# 2.0518076e-08
# 1.3603025e-08
# 1.2941984e-08
# 7.4341986e-09
# 1.5443415e-08
# 1.0864851e-08
# 6.434156e-09
# 5.888233e-09
# 1.460841e-08
# 5.408997e-09
# 1.5759273e-08
# 1.2543194e-08
# 1.6338104e-08
# 1.4387156e-08
# 1.0478729e-08
# 1.0719907e-08
# 1.2510371e-08
# 1.0135426e-08
# 6.232246e-09
# 5.396921e-09
# 1.53857e-08
# 7.6513205e-09
# 6.867906e-09
# 8.482547e-09
# 1.08873275e-08
# 1.34682905e-08
# 1.4575718e-08
# 5.3342633e-09
# 3.6531291e-09
# 5.8604823e-09
# 1.8051457e-08
# 3.2517828e-09
# 7.6336235e-09
# 9.035653e-09
# 3.8513495e-09
# 1.3745795e-08
# 1.0179308e-08
# 7.894642e-09
# 1.0138222e-08
# 1.6011558e-08
# 1.2935061e-08
# 8.126203e-09
# 6.305459e-09
# 8.532219e-09
# 1.2772676e-08
# 7.795565e-09
# 1.0220221e-08
# 9.685239e-09
# 4.601627e-09
# 2.4235707e-08
# 5.059547e-09
# 9.771636e-09
# 6.1200787e-09
# 6.8982695e-09
# 1.0300821e-08
# 3.0147955e-08
# 7.830522e-09
# 9.296329e-09
# 6.317638e-09
# 7.3242234e-09
# 1.4967545e-08
# 9.119523e-09
# 6.379912e-09
# 1.38102125e-08
# 3.2478024e-08
# 1.2843211e-08
# 1.7919438e-08
# 1.2190134e-08
# 7.3103172e-09
# 1.2853455e-08
# 1.9770644e-08
# 1.0143343e-08
# 6.485248e-09
# 1.1379853e-08
# 3.765603e-09
# 3.811917e-09
# 1.3044337e-08
# 7.920387e-09
# 8.117857e-09
# 6.5801276e-09
# 7.7656965e-09
# 8.201697e-09
# 1.2811884e-08
# 1.2842522e-08
# 1.06085984e-08
# 1.6421955e-08
# 1.44703405e-08
# 1.7742982e-08
# 7.1088553e-09
# 5.6051017e-09
# 8.437006e-09
# 2.1306617e-08
# 1.2388888e-08
# 1.9192507e-08
# 9.470344e-09
# 8.931095e-09
# 1.6535466e-08
# 8.127312e-09
# 1.4874405e-08
# 1.052605e-08
# 1.6269427e-08
# 1.7501689e-08
# 7.912819e-09
# 3.727446e-08
# 8.954323e-09
# 7.539313e-09
# 7.485639e-09
# 1.5808306e-08
# 9.231154e-09
# 1.2844666e-08
# 8.0890405e-09
# 8.140229e-09
# 1.3619001e-08
# 6.56311e-09
# 2.2767201e-08
# 9.001254e-09
# 8.8859595e-09
# 4.3920267e-09
# 5.521492e-09
# 1.6005394e-08
# 1.1210144e-08
# 6.8305157e-09
# 9.205156e-09
# 1.4254823e-08
# 1.01811075e-08
# 6.8202994e-09
# 1.1209011e-08
# 7.365853e-09
# 1.3610829e-08
# 4.6980575e-09
# 4.746244e-09
# 6.677503e-09
# 7.068518e-09
# 9.294422e-09
# 1.26905375e-08
# 7.7959e-09
# 1.1337796e-08
# 6.4732752e-09
# 1.0466442e-08
# 4.8532e-09
# 1.569691e-08
# 6.6899633e-09
# 8.334195e-09
# 7.59884e-09
# 3.1972938e-08
# 6.8262938e-09
# 1.5691993e-08
# 9.30681e-09
# 4.9685838e-09
# 5.241498e-09
# 7.666995e-09
# 1.00555715e-08
# 8.226819e-09
# 9.409027e-09
# 1.5352478e-08
# 5.3567364e-09
# 1.1807987e-08
# 6.7161587e-09
# 2.0371013e-08
# 8.103348e-09
# 1.7860183e-08
# 6.8524457e-09
# 9.466746e-09
# 9.076088e-09
# 7.98375e-09
# 1.0480718e-08
# 2.1235392e-08
# 7.3490156e-09
# 6.72097e-09
# 1.432091e-08
# 1.6115562e-08
# 5.9523364e-09
# 7.4020448e-09
# 7.491221e-09
# 5.2428315e-09
# 1.4464328e-08
# 1.6476813e-08
# 6.45328e-09
# 8.037291e-09
# 9.334016e-09
# 7.370353e-09
# 6.203508e-09
# 1.2810219e-08
# 1.3122587e-08
# 2.1443462e-08
# 2.6145356e-08
# 8.623248e-09
# 8.665867e-09
# 9.121391e-09
# 5.5938663e-09
# 7.990346e-09
# 1.0932365e-08
# 1.09369305e-08
# 1.8558863e-08
# 8.748716e-09
# 5.0224878e-09
# 4.71134e-09
# 1.8460367e-08
# 1.4090148e-08
# 9.608786e-09
# 1.2647606e-08
# 5.2452136e-09
# 1.1066314e-08
# 1.2395897e-08
# 7.535192e-09
# 1.0144209e-08
# 5.166473e-09
# 1.1120366e-08
# 1.18860255e-08
# 8.297341e-09
# 8.198443e-09
# 6.5851866e-09
# 6.658695e-09
# 1.2734026e-08
# 2.6249976e-08
# 6.3344543e-09
# 4.4622485e-08
# 1.6556774e-08
# 1.5531572e-08
# 8.5017575e-09
# 8.3944505e-09
# 8.196016e-09
# 1.2359465e-08
# 5.933439e-09
# 1.1594412e-08
# 1.2895308e-08
# 8.20286e-09
# 1.18270815e-08
# 1.06966445e-08
# 1.12968195e-08
# 1.0535509e-08
# 1.0726752e-08
# 4.2626738e-09
# 1.1170999e-08
# 4.5277426e-09
# 1.3938319e-08
# 1.0059488e-08
# 9.730754e-09
# 3.0321953e-08
# 6.6718147e-09
# 6.2041523e-09
# 6.1674714e-09
# 1.5384424e-08
# 1.3241302e-08
# 8.396893e-09
# 7.438179e-09
# 4.1066057e-09
# 1.0721908e-08
# 4.05109e-09
# 1.0128416e-08
# 6.9382353e-09
# 1.9330962e-08
# 1.1228887e-08
# 1.2500857e-08
# 6.3454033e-09
# 5.7075944e-09
# 6.816451e-09
# 1.244054e-08
# 6.2715912e-09
# 1.2405204e-08
# 9.340799e-09
# 1.5583725e-08
# 1.1023925e-08
# 5.3976215e-09
# 2.50469e-08
# 1.5865306e-08
# 7.1323614e-09
# 1.4066873e-08
# 9.970103e-09
# 1.6489926e-08
# 8.987363e-09
# 8.850759e-09
# 5.9288676e-09
# 5.242434e-09
# 5.3121902e-09
# 5.3436042e-09
# 1.0731429e-08
# 1.3539867e-08
# 9.876797e-09
# 1.7341755e-08
# 1.6602133e-08
# 8.808188e-09
# 1.5649716e-08
# 1.8116799e-08
# 1.5653598e-08
# 1.955347e-08
# 1.5770114e-08
# 1.0374802e-08
# 1.0300624e-08
# 1.4632022e-08
# 4.7606163e-09
# 5.3237947e-09
# 1.3644533e-08
# 8.148331e-09
# 1.3934548e-08
# 1.1549218e-08
# 7.940103e-09
# 8.9077075e-09
# 1.33942635e-08
# 7.3897115e-09
# 1.5742192e-08
# 9.959059e-09
# 7.352749e-09
# 1.3032209e-08
# 1.4066162e-08
# 1.8585053e-08
# 1.5871294e-08
# 1.1070256e-08
# 1.2839336e-08
# 1.3758367e-08
# 8.445636e-09
# 8.7949985e-09
# 9.38149e-09
# 3.7540646e-09
# 1.1347663e-08
# 1.1397411e-08
# 1.5858037e-08
# 7.895092e-09
# 4.3880752e-09
# 8.273362e-09
# 5.717421e-09
# 1.641168e-08
# 1.0811855e-08
# 1.34261455e-08
# 2.8296972e-08
# 5.4858464e-09
# 8.212444e-09
# 4.384392e-09
# 7.713324e-09
# 6.842258e-09
# 6.385284e-09
# 1.574127e-08
# 8.715263e-09
# 1.1149775e-08
# 1.2306616e-08
# 1.5814173e-08
# 1.123591e-08
# 1.5828034e-08
# 8.9030365e-09
# 1.055957e-08
# 2.1893987e-08
# 7.871151e-09
# 3.0175716e-08
# 1.0308713e-08
# 1.8034097e-08
# 7.3846183e-09
# 9.939737e-09
# 7.0507506e-09
# 1.2877537e-08
# 1.2428228e-08
# 1.0953628e-08
# 1.070555e-08
# 8.379158e-09
# 7.6296685e-09
# 8.8065875e-09
# 1.750106e-08
# 1.4852232e-08
# 6.3632855e-09
# 2.6840835e-08
# 7.826451e-09
# 7.047892e-09
# 2.6275135e-08
# 7.0493074e-09
# 1.1885272e-08
# 2.1719755e-08
# 6.0221583e-09
# 1.1912332e-08
# 1.1747439e-08
# 6.202614e-09
# 5.7385505e-09
# 1.2010284e-08
# 1.3981281e-08
# 5.1555e-09
# 1.5432285e-08
# 1.2235108e-08
# 1.6201554e-08
# 5.4043774e-09
# 5.640315e-09
# 2.2138677e-08
# 8.6498915e-09
# 1.1426884e-08
# 1.3546684e-08
# 1.6977584e-08
# 1.2498683e-08
# 1.2874935e-08
# 1.6041172e-08
# 1.9019817e-08
# 6.867484e-09
# 9.137394e-09
# 1.2028122e-08
# 2.4246473e-08
# 3.4332275e-09
# 1.6309697e-08
# 1.4796981e-08
# 1.0462851e-08
# 1.8196234e-08
# 8.092498e-09
# 1.2079636e-08
# 1.18819e-08
# 1.3147118e-08
# 7.199703e-09
# 1.8467391e-08
# 7.060651e-09
# 1.6284341e-08
# 1.6987196e-08
# 4.1253743e-09
# 6.2665926e-09
# 3.0829263e-08
# 2.33098e-08
# 1.8717628e-08
# 7.044035e-09
# 3.9116426e-08
# 8.932767e-09
# 1.2197829e-08
# 1.06119575e-08
# 1.29092745e-08
# 6.9783512e-09
# 1.5667789e-08
# 7.993728e-09
# 7.974843e-09
# 1.4610541e-08
# 8.500134e-09
# 1.1628054e-08
# 2.8847632e-08
# 1.0164285e-08
# 1.7718662e-08
# 2.0147189e-08
# 1.9647766e-08
# 1.7383602e-08
# 1.9219831e-08
# 1.1694267e-08
# 1.1271842e-08
# 1.3836862e-08
# 1.7531496e-08
# 1.1064502e-08
# 1.5208027e-08
# 1.8519406e-08
# 1.0530655e-08
# 1.602443e-08
# 7.4002124e-09
# 6.037291e-09
# 9.201762e-09
# 2.8585282e-08
# 1.1879512e-08
# 6.0928245e-09
# 4.821932e-09
# 1.4213228e-08
# 9.892866e-09
# 1.0825727e-08
# 5.259763e-09
# 4.8465427e-08
# 5.272016e-09
# 1.87213e-08
# 7.0340174e-09
# 5.1259286e-09
# 4.7295488e-09
# 9.49493e-09
# 7.400679e-09
# 6.786276e-09
# 6.231496e-09
# 1.7564906e-08
# 8.158093e-09
# 2.4812966e-08
# 2.5165614e-08
# 1.7682646e-08
# 1.2713089e-08
# 7.272059e-09
# 1.2083492e-08
# 1.3731966e-08
# 9.127689e-09
# 1.7915204e-08
# 6.548223e-09
# 1.2242087e-08
# 1.0454769e-08
# 1.0130914e-08
# 1.3258379e-08
# 1.5819944e-08
# 9.903936e-09
# 1.0050054e-08
# 1.1874164e-08
# 7.516654e-09
# 2.1511951e-08
# 9.933599e-09
# 6.637318e-09
# 1.6432145e-08
# 1.38673775e-08
# 1.1645233e-08
# 1.06649365e-08
# 4.669391e-09
# 9.454598e-09
# 8.1425675e-09
# 5.581626e-09
# 1.0205457e-08
# 8.856072e-09
# 1.8343565e-08
# 1.29748186e-08
# 2.2441778e-08
# 1.0080469e-08
# 1.32055025e-08
# 4.892675e-08
# 1.1419603e-08
# 6.9378565e-09
# 1.1186896e-08
# 1.40474485e-08
# 8.819551e-09
# 1.6675015e-08
# 1.3409934e-08
# 2.0894147e-08
# 9.285595e-09
# 1.2144921e-08
# 1.0878263e-08
# 6.8010237e-09
# 1.46663925e-08
# 1.1145449e-08
# 2.0942897e-08
# 5.0751523e-09
# 1.19274235e-08
# 9.058155e-09
# 1.5639758e-08
# 1.2004759e-08
# 8.537486e-09
# 3.957148e-09
# 1.0758252e-08
# 9.93612e-09
# 9.371269e-09
# 1.05611635e-08
# 1.0820471e-08
# 8.287137e-09
# 3.7953862e-09
# 9.301209e-09
# 1.2779333e-08
# 6.943317e-09
# 1.6424659e-08
# 8.557467e-09
# 1.7938788e-08
# 1.220152e-08
# 1.0767443e-08
# 1.1958273e-08
# 9.2922745e-09
# 8.40022e-09
# 1.6151317e-08
# 1.037269e-08
# 1.4538954e-08
# 6.2633005e-09
# 5.3702207e-09
# 6.718077e-09
# 9.239911e-09
# 5.990454e-09
# 4.754573e-09
# 7.555541e-09
# 5.479586e-09
# 1.2410399e-08
# 6.961726e-09
# 1.0087329e-08
# 1.7039401e-08
# 6.4587184e-09
# 1.0872718e-08
# 6.8835284e-09
# 1.40644545e-08
# 1.0344514e-08
# 1.2805271e-08
# 1.1802164e-08
# 4.311862e-09
# 1.9898833e-08
# 1.7164828e-08
# 7.986574e-09
# 1.1140895e-08
# 8.194753e-09
# 6.182475e-09
# 1.1309969e-08
# 1.0069987e-08
# 1.002445e-08
# 6.0601706e-09
# 3.3156905e-08
# 7.461103e-09
# 1.9486572e-08
# 1.21943655e-08
# 6.4394117e-09
# 1.182966e-08
# 8.215491e-09
# 1.3146033e-08
# 2.549082e-08
# 1.2389551e-08
# 1.23498864e-08
# 9.640448e-09
# 5.1627755e-09
# 9.874876e-09
# 9.182977e-09
# 1.1461928e-08
# 2.201468e-08
# 8.10656e-09
# 2.100632e-08
# 1.1303273e-08
# 1.224424e-08
# 6.3153687e-09
# 1.2810861e-08
# 9.363745e-09
# 6.63402e-09
# 6.7977277e-09
# 2.673013e-08
# 7.188602e-09
# 3.6261305e-08
# 1.0621108e-08
# 1.0802189e-08
# 1.7361128e-08
# 1.2750147e-08
# 9.097632e-09
# 1.7986123e-08
# 5.1463473e-09
# 1.7916978e-08
# 1.7686437e-08
# 8.774521e-09
# 3.7342886e-08
# 1.075255e-08
# 2.000944e-08
# 1.3967119e-08
# 2.329019e-08
# 1.131752e-08
# 2.5708493e-08
# 1.8182758e-08
# 1.522751e-08
# 8.788034e-09
# 1.0932285e-08
# 8.544257e-09
# 6.8090444e-09
# 1.85057e-08
# 6.262276e-09
# 1.0163942e-08
# 1.21972334e-08
# 6.4554952e-09
# 7.008231e-09
# 1.1960505e-08
# 1.7180552e-08
# 5.8888547e-09
# 7.080041e-09
# 1.2433681e-08
# 2.0732994e-08
# 1.3832772e-08
# 8.32003e-09
# 5.6792153e-09
# 1.4762408e-08
# 5.09595e-09
# 7.618603e-09
# 1.1703128e-08
# 8.923403e-09
# 7.714141e-09
# 1.705267e-08
# 1.5094216e-08
# 5.206686e-09
# 1.9060385e-08
# 5.6711085e-09
# 7.607359e-09
# 8.095012e-09
# 2.6588651e-08
# 5.2783937e-09
# 1.805462e-08
# 1.5306986e-08
# 1.0675541e-08
# 4.114862e-09
# 2.6245463e-08
# 1.1842308e-08
# 8.453899e-09
# 5.6208114e-09
# 1.2751245e-08
# 1.4505602e-08
# 1.3697556e-08
# 1.2473103e-08
# 7.325629e-09
# 1.0914799e-08
# 1.4697392e-08
# 1.7899286e-08
# 1.4531344e-08
# 1.0242219e-08
# 8.170396e-09
# 1.30980835e-08
# 2.0313086e-08
# 6.35154e-09
# 1.3712037e-08
# 9.197591e-09
# 5.7730176e-09
# 1.2429623e-08
# 2.7141756e-08
# 2.0732916e-08
# 5.2361693e-09
# 1.1389793e-08
# 7.3275688e-09
# 1.4933988e-08
# 1.0668154e-08
# 2.9246005e-08
# 2.843025e-08
# 2.4213838e-08
# 1.8241698e-08
# 9.447588e-09
# 1.1375856e-08
# 6.789116e-09
# 4.902372e-09
# 9.385178e-09
# 8.425425e-09
# 1.0189736e-08
# 8.342224e-09
# 9.479244e-09
# 1.3699304e-08
# 4.0821044e-09
# 1.1407379e-08
# 2.4859716e-08
# 7.092865e-09
# 1.17205055e-08
# 9.662376e-09
# 9.520427e-09
# 2.2358007e-08
# 1.0670795e-08
# 1.3051914e-08
# 1.0982629e-08
# 6.332557e-09
# 1.3234725e-08
# 1.5136203e-08
# 9.946497e-09
# 1.0470515e-08
# 1.421561e-08
# 1.2364822e-08
# 8.429081e-09
# 8.04142e-09
# 9.708547e-09
# 1.420446e-08
# 1.7222279e-08
# 7.634958e-09
# 9.106528e-09
# 1.9636273e-08
# 1.5835242e-08
# 1.1150035e-08
# 9.321748e-09
# 1.7161943e-08
# 9.101398e-09
# 9.964674e-09
# 1.9147029e-08
# 1.9529196e-08
# 1.4966272e-08
# 1.2921896e-08
# 1.4410881e-08
# 7.4342665e-09
# 5.917997e-09
# 8.730375e-09
# 3.2137855e-08
# 3.0551238e-08
# 9.278298e-09
# 2.832356e-08
# 1.7433422e-08
# 7.028196e-09
# 8.716508e-09
# 1.636098e-08
# 1.2603387e-08
# 6.2575e-09
# 8.283107e-09
# 9.534463e-09
# 7.625823e-09
# 2.7463207e-08
# 1.0191754e-08
# 1.1801926e-08
# 7.523428e-09
# 1.0363506e-08
# 1.727175e-08
# 1.1363793e-08
# 8.578827e-09
# 5.66763e-09
# 1.3792169e-08
# 1.4467014e-08
# 2.4498908e-08
# 9.235625e-09
# 1.0636579e-08
# 7.54548e-09
# 8.353898e-09
# 4.788572e-09
# 1.575431e-08
# 9.566047e-09
# 1.086835e-08
# 1.0891037e-08
# 8.384529e-09
# 9.237005e-09
# 7.103935e-09
# 1.7123275e-08
# 9.024062e-09
# 2.586321e-09
# 1.2679481e-08
# 1.1297381e-08
# 1.328398e-08
# 1.247088e-08
# 1.2098603e-08
# 7.478699e-09
# 7.222777e-09
# 9.57359e-09
# 1.6770752e-08
# 2.0495223e-08
# 1.4979092e-08
# 7.8991205e-09
# 1.3295e-08
# 1.1154707e-08
# 8.883504e-09
# 8.216529e-09
# 2.7602374e-08
# 2.1912104e-08
# 8.370317e-09
# 1.0104126e-08
# 6.9290347e-09
# 1.0283203e-08
# 1.2042942e-08
# 8.036716e-09
# 5.294282e-09
# 8.363128e-09
# 9.532601e-09
# 4.1712527e-09
# 1.2221889e-08
# 1.0906995e-08
# 5.4267026e-09
# 1.784179e-08
# 4.6521014e-09
# 6.3660153e-09
# 9.795104e-09
# 2.9008167e-09
# 7.3238087e-09
# 3.880813e-09
# 8.311779e-09
# 1.1367106e-08
# 1.5181994e-08
# 9.396545e-09
# 1.119061e-08
# 5.6211085e-09
# 4.2166053e-09
# 1.3445167e-08
# 1.0000892e-08
# 3.1326473e-09
# 1.0382402e-08
# 7.831225e-09
# 1.9233957e-08
# 7.681883e-09
# 1.2390297e-08
# 8.951693e-09
# 9.392492e-09
# 1.4355142e-08
# 1.5920294e-08
# 9.1420365e-09
# 1.3036422e-08
# 7.653307e-09
# 9.522077e-09
# 6.7505797e-09
# 1.3358672e-08
# 5.9611382e-09
# 1.7568079e-08
# 1.3906536e-08
# 6.4895724e-09
# 2.6129769e-08
# 1.3650932e-08
# 1.1258638e-08
# 3.461692e-08
# 1.0162413e-08
# 7.646709e-09
# 6.963032e-09
# 1.4281537e-08
# 4.2818473e-09
# 1.8637122e-08
# 9.689983e-09
# 5.0494395e-09
# 9.895527e-09
# 8.350759e-09
# 4.8889306e-09
# 1.1206467e-08
# 1.0530758e-08
# 8.213833e-09
# 9.366877e-09
# 8.685179e-09
# 9.416433e-09
# 1.4652691e-08
# 3.83615e-09
# 1.6085234e-08
# 1.2539248e-08
# 9.28021e-09
# 5.0029647e-09
# 1.3145811e-08
# 6.247075e-09
# 7.2916224e-09
# 8.7042675e-09
# 5.4158855e-09
# 1.239195e-08
# 2.3358602e-08
# 2.0939114e-08
# 1.2922323e-08
# 1.6372104e-08
# 7.987781e-09
# 7.793302e-09
# 8.594603e-09
# 1.8127668e-08
# 7.4018445e-09
# 6.57482e-09
# 9.56416e-09
# 1.5678673e-08

# %% [markdown]
# ### Test the critic neural network

# %%
jit_v_critic = jax.jit(v_critic)
test_states = exp_pool.states

# test_states = test_states.at[:,0].set(jp.zeros(test_states.shape[0]))
test_states = test_states.at[:,1].set(jp.zeros(test_states.shape[0]))
test_states = test_states.at[:,2].set(jp.zeros(test_states.shape[0]))
test_states = test_states.at[:,3].set(jp.zeros(test_states.shape[0]))
scores = jit_v_critic(critic_params, exp_pool.states)
test_scores = jit_v_critic(critic_params, test_states)

plt.plot(scores)
plt.plot(test_scores)

# %% [markdown]
# ## Train the controller with the critic net without the differentiable simulator

# %%
# Reset Params
controller_params = controller.init(key,jp.empty([1, mjx_model.nq*2]),sub_keys[0])
tx = optax.adam(learning_rate=0.00001)
opt_state = tx.init(controller_params)
jit_tx_update = jax.jit(tx.update)
jit_apply_update = jax.jit(optax.apply_updates)
batch_size = 400
# Init data

# %%
v_controller = jax.vmap(controller.apply,in_axes=(None, 0))


def total_loss(controller_params, critic_params, batch, batch_size, mjx_model, keys):
    # batch_size = batch.states.shape[0]
    states = batch.states
    # Generate data for simulation
    in_data = reset(mjx_model, batch_size).replace(qpos = states[:,0:2], qvel = states[:,2:4])
    out_data, keys, exp = jit_v_nn_multi_steps(controller_params, mjx_model, in_data, keys)
    out_states = jp.stack([out_data.qpos, out_data.qvel], axis=1).reshape(batch_size,4)
    # jax.debug.print("out_states shape{0}", out_states.shape)
    critic_score = v_critic(critic_params, out_states)
    
    loss = -jp.mean(critic_score)
    return loss

jit_total_loss_grad_value = jax.jit(jax.value_and_grad(total_loss), static_argnames=["batch_size"])

# Test total_lose
# batch_size = 100
# batch = Memory.sample(exp_pool, batch_size, key)
# key = jax.random.split(key, 1)[0]
# keys = jax.random.split(key,batch_size)
# jit_total_loss = jax.jit(total_loss, static_argnames=["batch_size"])
# loss, grad = jit_total_loss_grad_value(controller_params, critic_params, batch, batch_size, mjx_model, keys)
# print(loss)

# %%
new_params = controller_params
for i in range(100):
    batch = Memory.sample(exp_pool, batch_size, key)
    key = jax.random.split(key, 1)[0]
    keys = jax.random.split(key,batch_size)
    loss, loss_grad = jit_total_loss_grad_value(new_params, critic_params, batch, batch_size, mjx_model, keys)
    print(loss)
    # Update params
    updates, opt_stats = jit_tx_update(loss_grad, opt_state)
    new_params = jit_apply_update(new_params, updates)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
controller_params = new_params

# %% [markdown]
# ## Train the controller with the critic net and the differentiable simulator

# %% [markdown]
# ## Short Horizon Gradient calculation

# %%
def change_shape(x):
    # print(x.shape)
    return x.reshape(batch_size*fock_size,-1) 
d = jax.tree.map(change_shape,datas)
print(d.qpos.shape)
print(datas.qpos.shape)

# %%
print(keys.shape)
kk = jax.vmap(jax.random.split, in_axes=(0,None))(keys, 5)
print(kk.shape)
k = jp.reshape(kk, jp.array(kk.shape))
print(k.shape)

[*kk.shape][1:]
# print(kk.shape)

# %% [markdown]
# ## Learn To generate Critic Neural Network

# %%
datas.qpos.shape
b = jp.stack([datas.qpos, datas.qvel], axis=1).reshape(datas.qpos.shape[0],-1)
print(b[0])
print(datas.qpos[0])
print(b.shape)

# %%
a = [[2,3,4]]
b = [6,7]
b += a
print(b)

# %%
jp.stack([datas.qpos, datas.qvel], axis=1).reshape(100,-1).shape
# Out:
# (100, 4)
