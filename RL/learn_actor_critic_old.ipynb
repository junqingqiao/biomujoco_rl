# %% [markdown]
# # Learn Actor Crititc

# %%
import numpy as np
import mediapy as media
import matplotlib.pyplot as plt


import os
# os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".60"

# Optionally, force JAX to preallocate memory.
# os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "true"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

# Setup environment variable for Nvidia GPU acceleration
os.environ['XLA_FLAGS'] = (
    '--xla_gpu_triton_gemm_any=True '
)
backend = 'gpu'
# backend = 'METAL'
# backend = 'cpu'

import jax
from jax import numpy as jp
import flax
import flax.linen as nn
import optax


# Enable compliation catch
jax.config.update("jax_compilation_cache_dir", "./jax_cache")
jax.config.update("jax_persistent_cache_min_entry_size_bytes", 0)
jax.config.update("jax_persistent_cache_min_compile_time_secs", 5)
# jax.config.update("jax_explain_cache_misses", True)

# Debug Nan
jax.config.update("jax_debug_nans", False)


# More legible printing from numpy.
jp.set_printoptions(precision=4, suppress=True, linewidth=100)

import mujoco
import mujoco.mjx as mjx
from mujoco.mjx._src import scan
from mujoco.mjx._src import types

# More legible printing from numpy.
np.set_printoptions(precision=4, suppress=True, linewidth=100)

from IPython.display import clear_output
clear_output()

device = jax.devices(backend=backend)[0]

model_path = '../model/inverted_pendulum.xml'

# Single step
mjx_step = jax.jit(mjx.step, backend=backend)



# mjx_multiple_steps = jax.jit(multiple_steps, backend=backend, )

# %% [markdown]
# ## Load Model

# %%
from mujoco.mjx._src.biomtu import acceleration_mtu

mj_model = mujoco.MjModel.from_xml_path(model_path)
mjx_model = mjx.put_model(mj_model,device=device)

# Disable tendon
opt = mjx_model.opt.replace(disableflags = mjx_model.opt.disableflags |mujoco.mjtDisableBit.mjDSBL_PASSIVE)
mjx_model = mjx_model.replace(opt=opt)

mjx_data = mjx.make_data(mjx_model)
mj_data = mujoco.MjData(mj_model)

# Load the Keyframe
# mjx_data = mjx_data.replace(qpos = mj_model.key_qpos[0])
# mj_data.qpos = mj_model.key_qpos[0]

# Calculate equilibrum
# mjx_data = acceleration_mtu.calc_equilibrium(mjx_model, mjx_data)
mjx_data = mjx_step(mjx_model, mjx_data)

# %% [markdown]
# ## Control Neural Network and Critic Neural Network
# For now this NN will only work for the inverted pendulum

# %%
class Controller_NN(nn.Module):
    out_dims = 1
    def setup(self):
        # Features means the output dimension
        self.linear1 = nn.Dense(features=400)
        self.linear2 = nn.Dense(features=400)
        self.linear3 = nn.Dense(features=400)
        self.linear4 = nn.Dense(features=400)
        # The last layer will output the mean and logstd
        self.linear5 = nn.Dense(features=self.out_dims*2)
        
    
    def __call__(self, x, key):
        x = self.linear1(x)
        x = nn.relu(x)
        x = self.linear2(x)
        x = nn.relu(x)
        x = self.linear3(x)
        x = nn.relu(x)
        x = self.linear4(x)
        x = nn.relu(x)
        x = self.linear5(x)
        # The last layer of the neural requires samping
        mean = x[0]
        logstd = x[1]
        std = jp.exp(logstd)
        # samples = jp.clip(jax.random.normal(key)*std*0.3 + mean, -3, 3)
        samples = jax.random.normal(key)*std*0.3 + mean
        
        return samples, mean, logstd

# Test the neural network
controller = Controller_NN()

# Init the model
key = jax.random.key(2024)
sub_keys = jax.random.split(key,1)
# The second parameter is the dommy input
controller_params = controller.init(key,jp.empty([1, mjx_model.nq*2]),sub_keys[0])
# print(params)
jit_controller = jax.jit(lambda params, states, key : controller.apply(params, states, key))

class Critic_NN(nn.Module):

    def setup(self):
        # Features means the output dimension
        self.linear1 = nn.Dense(features=400)
        self.linear2 = nn.Dense(features=400)
        self.linear3 = nn.Dense(features=400)
        self.linear4 = nn.Dense(features=400)
        # The last layer will output the mean and logstd
        self.linear5 = nn.Dense(features=1)
        
    
    def __call__(self, x):
        x = self.linear1(x)
        x = nn.relu(x)
        x = self.linear2(x)
        x = nn.relu(x)
        x = self.linear3(x)
        x = nn.relu(x)
        x = self.linear4(x)
        x = nn.relu(x)
        x = self.linear5(x)
        # The last layer of the neural requires samping
        return -nn.relu(x)

critic = Critic_NN()

# Init the critic neural network by providing the input dummy. The input dummy defines the input shape
key = jax.random.split(sub_keys[0],1)[0]
sub_key = jax.random.split(key,1)[0]

# The input for the qcritic neural network should be observations and actions
# For the obs=mjx_model.nq*2, actions=1
critic_params = critic.init(key, jp.empty([1,mjx_model.nq*2]))
jit_critic = jax.jit(lambda params, state_acts: critic.apply(params, state_acts))

# Test the two neural networks
print(jit_controller(controller_params, jp.ones(mjx_model.nq*2), sub_keys[0]))
print(jit_critic(critic_params, jp.ones(mjx_model.nq*2)))
# Out:
# (Array(0.4321, dtype=float32), Array(0.1207, dtype=float32), Array(-0.1315, dtype=float32))
# [-0.047]

# %% [markdown]
# ## Experience Control

# %%
from dataclasses import dataclass
import functools


# Register the Experience class as pytree
@functools.partial(jax.tree_util.register_dataclass,
                   data_fields=['states', 'next_states', 'actions', 'rewards'],
                   meta_fields=[])
@dataclass
class Experience(object):
    states : jax.Array
    next_states : jax.Array
    actions : jax.Array
    rewards : jax.Array
    # dones: jax.Array
    
    # def __init__(self, state, next_state, action, reward):
    #     self.state = state
    #     self.next_state = next_state
    #     self.action = action
    #     self.reward = reward



@functools.partial(jax.tree_util.register_dataclass,
                   data_fields=['max_size', 'state_shape', 'action_shape', 'reward_shape'],
                   meta_fields=[])
@dataclass(frozen=True)
class Memory_settings():
    max_size     : jax.Array
    state_shape  : jax.Array
    action_shape : jax.Array
    reward_shape : jax.Array


class Memory(): 
    
    @staticmethod
    def append_fn(exp_item, exp_pool_item):
        return jp.concatenate([exp_item, exp_pool_item],axis=0)
    
    @staticmethod
    def trim_fn(exp_pool_item, length):
        return exp_pool_item[:length]
    
    @staticmethod
    def sample_fn(exp_pool_item, index):
        return exp_pool_item[index]
    
    staticmethod
    @functools.partial(jax.jit, static_argnames="settings")
    def add_exp(settings:Memory_settings, exp_pool:Experience, exp:Experience):
        exp.states = jp.reshape(exp.states,(-1, settings.state_shape))
        exp.next_states = jp.reshape(exp.next_states,(-1, settings.state_shape))
        exp.actions = jp.reshape(exp.actions, (-1, settings.action_shape))
        exp.rewards = jp.reshape(exp.rewards, (-1, settings.reward_shape))
        
        if(exp_pool == None):
            exp_pool = exp
        else:
            exp_pool = jax.tree.map(Memory.append_fn, exp, exp_pool)
            
        len = exp_pool.states.shape[0]
        
        # Forget the outdated memory
        if(len> settings.max_size):
            exp_pool = jax.tree.map(lambda x: Memory.trim_fn(x, settings.max_size), exp_pool)
        
        return exp_pool
        
    @staticmethod
    @functools.partial(jax.jit, static_argnames="batch_size")
    def sample(exp_pool, batch_size, key)-> Experience :
        index = jax.random.choice(
            key,
            jp.arange(exp_pool.states.shape[0]),
            shape = (batch_size,),
            replace=False
        )
        return jax.tree.map(lambda x: Memory.sample_fn(x, index), exp_pool)

# %% [markdown]
# ## Multi-steps forward simulation

# %%
def step_fn(carry, _):
    data, model = carry
    new_data = mjx.step(model, data)
    new_carry = (new_data, model)
    return new_carry, _

def multiple_steps(model, data):
    init_carry = (data, model)
    y, _ = jax.lax.scan(step_fn, init_carry, None, length=10)
    new_data = y[0]
    return new_data

def nn_mjx_one_step(nn_params, model, data, key):
    states = jp.concatenate([data.qpos, data.qvel])
    act, mean, dev = jit_controller(nn_params, states, key)
    # Generate the next key
    new_key = jax.random.split(key,1)[0]
    data = data.replace(ctrl = jp.array([act]))
    new_data = mjx.step(model, data)
    return new_data, new_key, act

@jax.jit
def jit_nn_mjx_one_step_no_random(nn_params, model, data, key):
    states = jp.concatenate([data.qpos, data.qvel])
    act, mean, dev = jit_controller(nn_params, states, key)
    # Generate the next key
    new_key = jax.random.split(key,1)[0]
    data = data.replace(ctrl = jp.array([mean]))
    new_data = mjx.step(model, data)
    return new_data, new_key, mean

def nn_step_fn(carry, _):
    nn_params, model, data, key = carry
    new_data, new_key, act = nn_mjx_one_step(nn_params, model, data, key)
    new_carry = (nn_params, model, new_data, new_key)
    # Calculate reward
    state = jp.stack([data.qpos, data.qvel], axis=1).flatten()
    next_state = jp.stack([new_data.qpos, data.qvel], axis=1).flatten()
    action = act
    reward = -new_data.qpos[1]**2
    experience = Experience(state, next_state, action, reward)
    
    return new_carry, experience

def decay_sum_scan(x, decay):
    def f(sxtm1, xt):
        b = xt + decay * sxtm1
        return b, b
    return jax.lax.scan(f, jp.zeros(x.shape[1:]), x)[1]

@jax.jit
def jit_nn_multi_steps(nn_params, model, data, key):
    repeat_length = 5
    init_carry = (nn_params, model, data, key)
    y, experience = jax.lax.scan(nn_step_fn, init_carry, None, length=repeat_length)
    new_data = y[2]
    new_key = y[3]
    
    return new_data, new_key, experience

@jax.jit
def jit_v_nn_multi_steps(nn_params, model, data, key):
    return jax.vmap(jit_nn_multi_steps, in_axes=(None, None, 0, 0))(nn_params, model, data, key)

# This function generate
@jax.jit
def jit_vv_nn_multi_steps(nn_params, model, data, key):
    return jax.vmap(jit_v_nn_multi_steps, in_axes=(None, None, None, 1))(nn_params, model, data, key)

# %% [markdown]
# ## Short Horizon Simulation & Gradient

# %% [markdown]
# ## Environment Control

# %%
# @jax.jit
def reset(model, batch_size):
    batch_dummy = jp.zeros(batch_size)
    v_make_data = jax.jit(jax.vmap(lambda model, batch_dummy: mjx.make_data(model), in_axes=(None,0),out_axes=0))
    new_datas = v_make_data(model, batch_dummy)
    return new_datas

# %% [markdown]
# ## Visualize the model and controller

# %%
import mujoco.viewer
import time


mjx_data = mjx.make_data(mjx_model)
mj_data = mujoco.MjData(mj_model)
previous_frame_time = time.time()
i = 0
key = jax.random.key(334)
with mujoco.viewer.launch_passive(mj_model, mj_data) as viewer:
    while viewer.is_running():
        # Update mjx_data from mj_data. The mj_data was modified by the viewer
        # mjx_data = mjx_data.replace(ctrl=mj_data.ctrl, xfrc_applied=mj_data.xfrc_applied)
        # Use the nerual network to generate ctrl signal
        # Generate key
        mjx_data = mjx_data.replace(xfrc_applied=jp.array(mj_data.xfrc_applied, dtype=jp.float32))
        mjx_data = mjx_data.replace(
            qpos= jp.array(mj_data.qpos, dtype=jp.float32),
            qvel= jp.array(mj_data.qvel, dtype=jp.float32),
            time = jp.array(mj_data.time, dtype=jp.float32))
        
        # Update mjx_model from mj_model
        mjx_model = mjx_model.tree_replace({
            'opt.gravity': jp.array(mj_model.opt.gravity, dtype=jp.float32),
            'opt.tolerance': jp.array(mj_model.opt.tolerance, dtype=jp.float32),
            'opt.ls_tolerance': jp.array(mj_model.opt.ls_tolerance, dtype=jp.float32),
            'opt.timestep': jp.array(mj_model.opt.timestep, dtype=jp.float32),
        })
        
        key = jax.random.split(key,1)[0]
        # mjx_data = mjx_step(mjx_model, mjx_data)
        # mjx_data, loss, exp = jit_nn_multi_steps(controller_params, mjx_model, mjx_data, key)
        mjx_data, key, act = jit_nn_mjx_one_step_no_random(controller_params, mjx_model, mjx_data, key)
        mjx.get_data_into(mj_data, mj_model, mjx_data)
        
        # Record the current time at the start of this frame
        current_frame_time = time.time()
    
        # Calculate the difference in time from the last frame
        time_between_frames = current_frame_time - previous_frame_time
    
        # Print the time between frames
        print(f"Time between frames: {time_between_frames} seconds")
        previous_frame_time = current_frame_time
        
        # print("ACT:", mjx_data.biomtu.act)
        # print(mjx_data.qpos)
        # print(mjx_data.sensordata)
        # print(len(mjx_data.qvel))
        viewer.sync()
# Out:
# Time between frames: 3.883836507797241 seconds
# Time between frames: 3.370297908782959 seconds
# Time between frames: 0.006546735763549805 seconds
# Time between frames: 0.005707502365112305 seconds
# Time between frames: 0.006098747253417969 seconds
# Time between frames: 0.00507044792175293 seconds
# Time between frames: 0.005956411361694336 seconds
# Time between frames: 0.004901409149169922 seconds
# Time between frames: 0.0050640106201171875 seconds
# Time between frames: 0.004992961883544922 seconds
# Time between frames: 0.00589299201965332 seconds
# Time between frames: 0.005082368850708008 seconds
# Time between frames: 0.005137920379638672 seconds
# Time between frames: 0.005342721939086914 seconds
# Time between frames: 0.005442142486572266 seconds
# Time between frames: 0.005114316940307617 seconds
# Time between frames: 0.0050618648529052734 seconds
# Time between frames: 0.005751848220825195 seconds
# Time between frames: 0.005014657974243164 seconds
# Time between frames: 0.0051038265228271484 seconds
# Time between frames: 0.005092620849609375 seconds
# Time between frames: 0.0058917999267578125 seconds
# Time between frames: 0.005578041076660156 seconds
# Time between frames: 0.005901813507080078 seconds
# Time between frames: 0.0050890445709228516 seconds
# Time between frames: 0.0052509307861328125 seconds
# Time between frames: 0.005401611328125 seconds
# Time between frames: 0.006265163421630859 seconds
# Time between frames: 0.006280183792114258 seconds
# Time between frames: 0.0062139034271240234 seconds
# Time between frames: 0.004893302917480469 seconds
# Time between frames: 0.006470441818237305 seconds
# Time between frames: 0.005026578903198242 seconds
# Time between frames: 0.0052564144134521484 seconds
# Time between frames: 0.005995512008666992 seconds
# Time between frames: 0.005207538604736328 seconds
# Time between frames: 0.004934549331665039 seconds
# Time between frames: 0.0050470829010009766 seconds
# Time between frames: 0.006212711334228516 seconds
# Time between frames: 0.005417346954345703 seconds
# Time between frames: 0.00620579719543457 seconds
# Time between frames: 0.0053064823150634766 seconds
# Time between frames: 0.005221366882324219 seconds
# Time between frames: 0.005667209625244141 seconds
# Time between frames: 0.005967855453491211 seconds
# Time between frames: 0.0057866573333740234 seconds
# Time between frames: 0.00537419319152832 seconds
# Time between frames: 0.005174160003662109 seconds
# Time between frames: 0.005334138870239258 seconds
# Time between frames: 0.005015373229980469 seconds
# Time between frames: 0.005104541778564453 seconds
# Time between frames: 0.0051119327545166016 seconds
# Time between frames: 0.005474567413330078 seconds
# Time between frames: 0.0053119659423828125 seconds
# Time between frames: 0.005105733871459961 seconds
# Time between frames: 0.005260467529296875 seconds
# Time between frames: 0.005180835723876953 seconds
# Time between frames: 0.005242347717285156 seconds
# Time between frames: 0.00594019889831543 seconds
# Time between frames: 0.005151987075805664 seconds
# Time between frames: 0.005120992660522461 seconds
# Time between frames: 0.006262540817260742 seconds
# Time between frames: 0.005536317825317383 seconds
# Time between frames: 0.00596928596496582 seconds
# Time between frames: 0.005431175231933594 seconds
# Time between frames: 0.00535273551940918 seconds
# Time between frames: 0.005698204040527344 seconds
# Time between frames: 0.005146980285644531 seconds
# Time between frames: 0.00624537467956543 seconds
# Time between frames: 0.0056078433990478516 seconds
# Time between frames: 0.005410432815551758 seconds
# Time between frames: 0.005536794662475586 seconds
# Time between frames: 0.005867719650268555 seconds
# Time between frames: 0.00574493408203125 seconds
# Time between frames: 0.005372762680053711 seconds
# Time between frames: 0.005654573440551758 seconds
# Time between frames: 0.005537986755371094 seconds
# Time between frames: 0.006595611572265625 seconds
# Time between frames: 0.006751060485839844 seconds
# Time between frames: 0.006567478179931641 seconds
# Time between frames: 0.005544424057006836 seconds
# Time between frames: 0.006544351577758789 seconds
# Time between frames: 0.005683183670043945 seconds
# Time between frames: 0.005684614181518555 seconds
# Time between frames: 0.005516767501831055 seconds
# Time between frames: 0.0063323974609375 seconds
# Time between frames: 0.006374835968017578 seconds
# Time between frames: 0.005545616149902344 seconds
# Time between frames: 0.006180524826049805 seconds
# Time between frames: 0.005719184875488281 seconds
# Time between frames: 0.005604267120361328 seconds
# Time between frames: 0.005186557769775391 seconds
# Time between frames: 0.005492687225341797 seconds
# Time between frames: 0.006219148635864258 seconds
# Time between frames: 0.0055217742919921875 seconds
# Time between frames: 0.005289793014526367 seconds
# Time between frames: 0.005007743835449219 seconds
# Time between frames: 0.005267620086669922 seconds
# Time between frames: 0.005705595016479492 seconds
# Time between frames: 0.005637168884277344 seconds
# Time between frames: 0.005494117736816406 seconds
# Time between frames: 0.0059778690338134766 seconds
# Time between frames: 0.00525665283203125 seconds
# Time between frames: 0.006213188171386719 seconds
# Time between frames: 0.005414485931396484 seconds
# Time between frames: 0.005435943603515625 seconds
# Time between frames: 0.005387306213378906 seconds
# Time between frames: 0.006228923797607422 seconds
# Time between frames: 0.005766868591308594 seconds
# Time between frames: 0.005751371383666992 seconds
# Time between frames: 0.004967212677001953 seconds
# Time between frames: 0.0055789947509765625 seconds
# Time between frames: 0.006173610687255859 seconds
# Time between frames: 0.005408763885498047 seconds
# Time between frames: 0.0060634613037109375 seconds
# Time between frames: 0.005026340484619141 seconds
# Time between frames: 0.005475521087646484 seconds
# Time between frames: 0.005888462066650391 seconds
# Time between frames: 0.0053081512451171875 seconds
# Time between frames: 0.005431175231933594 seconds
# Time between frames: 0.0062558650970458984 seconds
# Time between frames: 0.00533604621887207 seconds
# Time between frames: 0.005490541458129883 seconds
# Time between frames: 0.0051271915435791016 seconds
# Time between frames: 0.005950450897216797 seconds
# Time between frames: 0.0051043033599853516 seconds
# Time between frames: 0.005341291427612305 seconds
# Time between frames: 0.005995988845825195 seconds
# Time between frames: 0.005348920822143555 seconds
# Time between frames: 0.005810260772705078 seconds
# Time between frames: 0.005289793014526367 seconds
# Time between frames: 0.005301475524902344 seconds
# Time between frames: 0.006151914596557617 seconds
# Time between frames: 0.005411624908447266 seconds
# Time between frames: 0.00586700439453125 seconds
# Time between frames: 0.005296468734741211 seconds
# Time between frames: 0.0052204132080078125 seconds
# Time between frames: 0.006369352340698242 seconds
# Time between frames: 0.006348133087158203 seconds
# Time between frames: 0.005376577377319336 seconds
# Time between frames: 0.006053447723388672 seconds
# Time between frames: 0.005229473114013672 seconds
# Time between frames: 0.005311250686645508 seconds
# Time between frames: 0.006010770797729492 seconds
# Time between frames: 0.005202054977416992 seconds
# Time between frames: 0.0059871673583984375 seconds
# Time between frames: 0.005395174026489258 seconds
# Time between frames: 0.005631446838378906 seconds
# Time between frames: 0.006329536437988281 seconds
# Time between frames: 0.006699085235595703 seconds
# Time between frames: 0.006500244140625 seconds
# Time between frames: 0.005532503128051758 seconds
# Time between frames: 0.0061337947845458984 seconds
# Time between frames: 0.006186246871948242 seconds
# Time between frames: 0.005473136901855469 seconds
# Time between frames: 0.006099700927734375 seconds
# Time between frames: 0.00824594497680664 seconds
# Time between frames: 0.006226301193237305 seconds
# Time between frames: 0.005530834197998047 seconds
# Time between frames: 0.006128787994384766 seconds
# Time between frames: 0.005810260772705078 seconds
# Time between frames: 0.008141756057739258 seconds
# Time between frames: 0.005485057830810547 seconds
# Time between frames: 0.005999565124511719 seconds
# Time between frames: 0.006120443344116211 seconds
# Time between frames: 0.007372617721557617 seconds
# Time between frames: 0.005336284637451172 seconds
# Time between frames: 0.005071878433227539 seconds
# Time between frames: 0.006079435348510742 seconds
# Time between frames: 0.0051877498626708984 seconds
# Time between frames: 0.0058443546295166016 seconds
# Time between frames: 0.0050890445709228516 seconds
# Time between frames: 0.005091667175292969 seconds
# Time between frames: 0.005972146987915039 seconds
# Time between frames: 0.00523066520690918 seconds
# Time between frames: 0.006015300750732422 seconds
# Time between frames: 0.0051097869873046875 seconds
# Time between frames: 0.005170345306396484 seconds
# Time between frames: 0.005163431167602539 seconds
# Time between frames: 0.0059397220611572266 seconds
# Time between frames: 0.005632877349853516 seconds
# Time between frames: 0.005570888519287109 seconds
# Time between frames: 0.0056803226470947266 seconds
# Time between frames: 0.006556034088134766 seconds
# Time between frames: 0.005423307418823242 seconds
# Time between frames: 0.00632786750793457 seconds
# Time between frames: 0.006216287612915039 seconds
# Time between frames: 0.005385637283325195 seconds
# Time between frames: 0.005745410919189453 seconds
# Time between frames: 0.006304264068603516 seconds
# Time between frames: 0.006402730941772461 seconds
# Time between frames: 0.005444765090942383 seconds
# Time between frames: 0.0061037540435791016 seconds
# Time between frames: 0.005694150924682617 seconds
# Time between frames: 0.005234479904174805 seconds
# Time between frames: 0.00539708137512207 seconds
# Time between frames: 0.005028247833251953 seconds
# Time between frames: 0.0058400630950927734 seconds
# Time between frames: 0.005112886428833008 seconds
# Time between frames: 0.005063056945800781 seconds
# Time between frames: 0.006081104278564453 seconds
# Time between frames: 0.005142927169799805 seconds
# Time between frames: 0.0050525665283203125 seconds
# Time between frames: 0.005357027053833008 seconds
# Time between frames: 0.006086111068725586 seconds
# Time between frames: 0.005985260009765625 seconds
# Time between frames: 0.005265474319458008 seconds
# Time between frames: 0.006788015365600586 seconds
# Time between frames: 0.005466461181640625 seconds
# Time between frames: 0.005350828170776367 seconds
# Time between frames: 0.006219148635864258 seconds
# Time between frames: 0.006478786468505859 seconds
# Time between frames: 0.0051767826080322266 seconds
# Time between frames: 0.005689859390258789 seconds
# Time between frames: 0.005406379699707031 seconds
# Time between frames: 0.005399227142333984 seconds
# Time between frames: 0.006327390670776367 seconds
# Time between frames: 0.006292581558227539 seconds
# Time between frames: 0.006033420562744141 seconds
# Time between frames: 0.006123542785644531 seconds
# Time between frames: 0.006275653839111328 seconds
# Time between frames: 0.005438566207885742 seconds
# Time between frames: 0.006110668182373047 seconds
# Time between frames: 0.008292675018310547 seconds
# Time between frames: 0.0060346126556396484 seconds
# Time between frames: 0.005212545394897461 seconds
# Time between frames: 0.006162405014038086 seconds
# Time between frames: 0.00525975227355957 seconds
# Time between frames: 0.005975484848022461 seconds
# Time between frames: 0.005409717559814453 seconds
# Time between frames: 0.0050809383392333984 seconds
# Time between frames: 0.005697488784790039 seconds
# Time between frames: 0.005072832107543945 seconds
# Time between frames: 0.005548954010009766 seconds
# Time between frames: 0.005524396896362305 seconds
# Time between frames: 0.005421161651611328 seconds
# Time between frames: 0.005417346954345703 seconds
# Time between frames: 0.005471467971801758 seconds
# Time between frames: 0.005334615707397461 seconds
# Time between frames: 0.004997730255126953 seconds
# Time between frames: 0.006300210952758789 seconds
# Time between frames: 0.005179166793823242 seconds
# Time between frames: 0.0061037540435791016 seconds
# Time between frames: 0.005387783050537109 seconds
# Time between frames: 0.005271434783935547 seconds
# Time between frames: 0.006201028823852539 seconds
# Time between frames: 0.006179332733154297 seconds
# Time between frames: 0.005082130432128906 seconds
# Time between frames: 0.005362033843994141 seconds
# Time between frames: 0.005321025848388672 seconds
# Time between frames: 0.006690025329589844 seconds
# Time between frames: 0.007379055023193359 seconds
# Time between frames: 0.008267879486083984 seconds
# Time between frames: 0.006339311599731445 seconds
# Time between frames: 0.005448579788208008 seconds
# Time between frames: 0.006123542785644531 seconds
# Time between frames: 0.005316495895385742 seconds
# Time between frames: 0.0056765079498291016 seconds
# Time between frames: 0.005103588104248047 seconds
# Time between frames: 0.005074024200439453 seconds
# Time between frames: 0.005861759185791016 seconds
# Time between frames: 0.005124568939208984 seconds
# Time between frames: 0.005108833312988281 seconds
# Time between frames: 0.0050427913665771484 seconds
# Time between frames: 0.005846977233886719 seconds
# Time between frames: 0.005037069320678711 seconds
# Time between frames: 0.005129814147949219 seconds
# Time between frames: 0.0050847530364990234 seconds
# Time between frames: 0.0059587955474853516 seconds
# Time between frames: 0.005250692367553711 seconds
# Time between frames: 0.005998849868774414 seconds
# Time between frames: 0.005207061767578125 seconds
# Time between frames: 0.0051462650299072266 seconds
# Time between frames: 0.005933523178100586 seconds
# Time between frames: 0.005269050598144531 seconds
# Time between frames: 0.0058710575103759766 seconds
# Time between frames: 0.005380153656005859 seconds
# Time between frames: 0.006142139434814453 seconds
# Time between frames: 0.0055806636810302734 seconds
# Time between frames: 0.005050182342529297 seconds
# Time between frames: 0.005565643310546875 seconds
# Time between frames: 0.0052793025970458984 seconds
# Time between frames: 0.005353689193725586 seconds
# Time between frames: 0.006096839904785156 seconds
# Time between frames: 0.004973649978637695 seconds
# Time between frames: 0.005091428756713867 seconds
# Time between frames: 0.005122661590576172 seconds
# Time between frames: 0.005870819091796875 seconds
# Time between frames: 0.0052454471588134766 seconds
# Time between frames: 0.005800724029541016 seconds
# Time between frames: 0.0052411556243896484 seconds
# Time between frames: 0.005365133285522461 seconds
# Time between frames: 0.006173133850097656 seconds
# Time between frames: 0.005378007888793945 seconds
# Time between frames: 0.006072521209716797 seconds
# Time between frames: 0.006601810455322266 seconds
# Time between frames: 0.004923820495605469 seconds
# Time between frames: 0.004987239837646484 seconds
# Time between frames: 0.004969120025634766 seconds
# Time between frames: 0.005925178527832031 seconds
# Time between frames: 0.005290508270263672 seconds
# Time between frames: 0.005132436752319336 seconds
# Time between frames: 0.005959272384643555 seconds
# Time between frames: 0.004913330078125 seconds
# Time between frames: 0.005414724349975586 seconds
# Time between frames: 0.0053822994232177734 seconds
# Time between frames: 0.00534510612487793 seconds
# Time between frames: 0.005320549011230469 seconds
# Time between frames: 0.005971431732177734 seconds
# Time between frames: 0.006730794906616211 seconds
# Time between frames: 0.005496978759765625 seconds
# Time between frames: 0.00553584098815918 seconds
# Time between frames: 0.0061304569244384766 seconds
# Time between frames: 0.0061435699462890625 seconds
# Time between frames: 0.005477190017700195 seconds
# Time between frames: 0.0062067508697509766 seconds
# Time between frames: 0.005261659622192383 seconds
# Time between frames: 0.0052204132080078125 seconds
# Time between frames: 0.006039857864379883 seconds
# Time between frames: 0.0051116943359375 seconds
# Time between frames: 0.005856513977050781 seconds
# Time between frames: 0.005351066589355469 seconds
# Time between frames: 0.005625724792480469 seconds
# Time between frames: 0.0062448978424072266 seconds
# Time between frames: 0.006583213806152344 seconds
# Time between frames: 0.0052297115325927734 seconds
# Time between frames: 0.005936145782470703 seconds
# Time between frames: 0.005412101745605469 seconds
# Time between frames: 0.005410194396972656 seconds
# Time between frames: 0.00580143928527832 seconds
# Time between frames: 0.005285501480102539 seconds
# Time between frames: 0.006093263626098633 seconds
# Time between frames: 0.0052700042724609375 seconds
# Time between frames: 0.005354166030883789 seconds
# Time between frames: 0.005942583084106445 seconds
# Time between frames: 0.0062143802642822266 seconds
# Time between frames: 0.005441427230834961 seconds
# Time between frames: 0.005944967269897461 seconds
# Time between frames: 0.005336761474609375 seconds
# Time between frames: 0.005407810211181641 seconds
# Time between frames: 0.0060384273529052734 seconds
# Time between frames: 0.005417585372924805 seconds
# Time between frames: 0.0063343048095703125 seconds
# Time between frames: 0.005347728729248047 seconds
# Time between frames: 0.005282402038574219 seconds
# Time between frames: 0.00563359260559082 seconds
# Time between frames: 0.007317781448364258 seconds
# Time between frames: 0.006893157958984375 seconds
# Time between frames: 0.006059169769287109 seconds
# Time between frames: 0.005378246307373047 seconds
# Time between frames: 0.006045341491699219 seconds
# Time between frames: 0.005346536636352539 seconds
# Time between frames: 0.006361484527587891 seconds
# Time between frames: 0.005121707916259766 seconds
# Time between frames: 0.005154609680175781 seconds
# Time between frames: 0.006396770477294922 seconds
# Time between frames: 0.006064891815185547 seconds
# Time between frames: 0.005747556686401367 seconds
# Time between frames: 0.00529026985168457 seconds
# Time between frames: 0.006131649017333984 seconds
# Time between frames: 0.00536036491394043 seconds
# Time between frames: 0.0061457157135009766 seconds
# Time between frames: 0.006179094314575195 seconds
# Time between frames: 0.005555629730224609 seconds
# Time between frames: 0.005392789840698242 seconds
# Time between frames: 0.006119728088378906 seconds
# Time between frames: 0.005265712738037109 seconds
# Time between frames: 0.00606536865234375 seconds
# Time between frames: 0.0055577754974365234 seconds
# Time between frames: 0.005628108978271484 seconds
# Time between frames: 0.0054492950439453125 seconds
# Time between frames: 0.006174564361572266 seconds
# Time between frames: 0.005475044250488281 seconds
# Time between frames: 0.005987405776977539 seconds
# Time between frames: 0.0052454471588134766 seconds
# Time between frames: 0.005499362945556641 seconds
# Time between frames: 0.006134986877441406 seconds
# Time between frames: 0.005574464797973633 seconds
# Time between frames: 0.005700111389160156 seconds
# Time between frames: 0.005279541015625 seconds
# Time between frames: 0.005445003509521484 seconds
# Time between frames: 0.0059511661529541016 seconds
# Time between frames: 0.005175352096557617 seconds
# Time between frames: 0.005531787872314453 seconds
# Time between frames: 0.005322456359863281 seconds
# Time between frames: 0.005403757095336914 seconds
# Time between frames: 0.006131172180175781 seconds
# Time between frames: 0.005258798599243164 seconds
# Time between frames: 0.005903959274291992 seconds
# Time between frames: 0.006063699722290039 seconds
# Time between frames: 0.005183219909667969 seconds
# Time between frames: 0.005589723587036133 seconds
# Time between frames: 0.006010532379150391 seconds
# Time between frames: 0.0052340030670166016 seconds
# Time between frames: 0.005955219268798828 seconds
# Time between frames: 0.005331277847290039 seconds
# Time between frames: 0.005261898040771484 seconds
# Time between frames: 0.005627632141113281 seconds
# Time between frames: 0.005612850189208984 seconds
# Time between frames: 0.006163597106933594 seconds
# Time between frames: 0.005557537078857422 seconds
# Time between frames: 0.005530118942260742 seconds
# Time between frames: 0.0061571598052978516 seconds
# Time between frames: 0.005474090576171875 seconds
# Time between frames: 0.005519866943359375 seconds
# Time between frames: 0.00596308708190918 seconds
# Time between frames: 0.0050313472747802734 seconds
# Time between frames: 0.0056536197662353516 seconds
# Time between frames: 0.005123138427734375 seconds
# Time between frames: 0.0058743953704833984 seconds
# Time between frames: 0.005323886871337891 seconds
# Time between frames: 0.005231380462646484 seconds
# Time between frames: 0.006261587142944336 seconds
# Time between frames: 0.005295753479003906 seconds
# Time between frames: 0.005570173263549805 seconds
# Time between frames: 0.0053827762603759766 seconds
# Time between frames: 0.005200386047363281 seconds
# Time between frames: 0.00606989860534668 seconds
# Time between frames: 0.005038738250732422 seconds
# Time between frames: 0.0058019161224365234 seconds
# Time between frames: 0.005269289016723633 seconds
# Time between frames: 0.00521540641784668 seconds
# Time between frames: 0.006252765655517578 seconds
# Time between frames: 0.005551576614379883 seconds
# Time between frames: 0.006081819534301758 seconds
# Time between frames: 0.006155967712402344 seconds
# Time between frames: 0.005374908447265625 seconds
# Time between frames: 0.005217075347900391 seconds
# Time between frames: 0.005133628845214844 seconds
# Time between frames: 0.005810976028442383 seconds
# Time between frames: 0.005991220474243164 seconds
# Time between frames: 0.005290985107421875 seconds
# Time between frames: 0.0056493282318115234 seconds
# Time between frames: 0.006211519241333008 seconds
# Time between frames: 0.00554966926574707 seconds
# Time between frames: 0.005977153778076172 seconds
# Time between frames: 0.006013393402099609 seconds
# Time between frames: 0.005245685577392578 seconds
# Time between frames: 0.005581378936767578 seconds
# Time between frames: 0.004916191101074219 seconds
# Time between frames: 0.00574946403503418 seconds
# Time between frames: 0.005219697952270508 seconds
# Time between frames: 0.005365133285522461 seconds
# Time between frames: 0.006000518798828125 seconds
# Time between frames: 0.004983186721801758 seconds
# Time between frames: 0.005539655685424805 seconds
# Time between frames: 0.005173921585083008 seconds
# Time between frames: 0.0057299137115478516 seconds
# Time between frames: 0.006018161773681641 seconds
# Time between frames: 0.005181312561035156 seconds
# Time between frames: 0.006503582000732422 seconds
# Time between frames: 0.006655693054199219 seconds
# Time between frames: 0.005431175231933594 seconds
# Time between frames: 0.005218029022216797 seconds
# Time between frames: 0.005365610122680664 seconds
# Time between frames: 0.005219936370849609 seconds
# Time between frames: 0.005704402923583984 seconds
# Time between frames: 0.005067110061645508 seconds
# Time between frames: 0.005993366241455078 seconds
# Time between frames: 0.005265235900878906 seconds
# Time between frames: 0.005649566650390625 seconds
# Time between frames: 0.005005598068237305 seconds
# Time between frames: 0.005196571350097656 seconds
# Time between frames: 0.005927324295043945 seconds
# Time between frames: 0.0051116943359375 seconds
# Time between frames: 0.0063343048095703125 seconds
# Time between frames: 0.004990816116333008 seconds
# Time between frames: 0.005022764205932617 seconds
# Time between frames: 0.005524873733520508 seconds
# Time between frames: 0.005160808563232422 seconds
# Time between frames: 0.005629539489746094 seconds
# Time between frames: 0.005276679992675781 seconds
# Time between frames: 0.0058667659759521484 seconds
# Time between frames: 0.005192279815673828 seconds
# Time between frames: 0.006248950958251953 seconds
# Time between frames: 0.007262229919433594 seconds
# Time between frames: 0.006360292434692383 seconds
# Time between frames: 0.005130290985107422 seconds
# Time between frames: 0.005261898040771484 seconds
# Time between frames: 0.005904197692871094 seconds
# Time between frames: 0.0051653385162353516 seconds
# Time between frames: 0.0059964656829833984 seconds
# Time between frames: 0.00511622428894043 seconds
# Time between frames: 0.0057392120361328125 seconds
# Time between frames: 0.006165981292724609 seconds
# Time between frames: 0.005079030990600586 seconds
# Time between frames: 0.005518436431884766 seconds
# Time between frames: 0.005214214324951172 seconds
# Time between frames: 0.005295515060424805 seconds
# Time between frames: 0.005087375640869141 seconds
# Time between frames: 0.005843162536621094 seconds
# Time between frames: 0.005467414855957031 seconds
# Time between frames: 0.005422115325927734 seconds
# Time between frames: 0.006056070327758789 seconds
# Time between frames: 0.005156517028808594 seconds
# Time between frames: 0.005816936492919922 seconds
# Time between frames: 0.006868124008178711 seconds
# Time between frames: 0.008634090423583984 seconds
# Time between frames: 0.007980585098266602 seconds
# Time between frames: 0.008442878723144531 seconds
# Time between frames: 0.006060361862182617 seconds
# Time between frames: 0.00622248649597168 seconds
# Time between frames: 0.005327463150024414 seconds
# Time between frames: 0.006203889846801758 seconds
# Time between frames: 0.0061800479888916016 seconds
# Time between frames: 0.005648612976074219 seconds
# Time between frames: 0.006259441375732422 seconds
# Time between frames: 0.006668806076049805 seconds
# Time between frames: 0.006691694259643555 seconds
# Time between frames: 0.005994081497192383 seconds
# Time between frames: 0.004973173141479492 seconds
# Time between frames: 0.005697011947631836 seconds
# Time between frames: 0.005099773406982422 seconds
# Time between frames: 0.0049016475677490234 seconds
# Time between frames: 0.00513768196105957 seconds
# Time between frames: 0.005534172058105469 seconds
# Time between frames: 0.00494694709777832 seconds
# Time between frames: 0.005536556243896484 seconds
# Time between frames: 0.005995750427246094 seconds
# Time between frames: 0.005182981491088867 seconds
# Time between frames: 0.005749225616455078 seconds
# Time between frames: 0.005146503448486328 seconds
# Time between frames: 0.005483865737915039 seconds
# Time between frames: 0.0051538944244384766 seconds
# Time between frames: 0.00554656982421875 seconds
# Time between frames: 0.004987955093383789 seconds
# Time between frames: 0.0051310062408447266 seconds
# Time between frames: 0.004931926727294922 seconds
# Time between frames: 0.005575895309448242 seconds
# Time between frames: 0.00496983528137207 seconds
# Time between frames: 0.006890058517456055 seconds
# Time between frames: 0.005585670471191406 seconds
# Time between frames: 0.0051648616790771484 seconds
# Time between frames: 0.0054090023040771484 seconds
# Time between frames: 0.005241870880126953 seconds
# Time between frames: 0.005342960357666016 seconds
# Time between frames: 0.0060100555419921875 seconds
# Time between frames: 0.0049419403076171875 seconds
# Time between frames: 0.005650043487548828 seconds
# Time between frames: 0.005603790283203125 seconds
# Time between frames: 0.00521087646484375 seconds
# Time between frames: 0.005190134048461914 seconds
# Time between frames: 0.0057582855224609375 seconds
# Time between frames: 0.005434751510620117 seconds
# Time between frames: 0.0050928592681884766 seconds
# Time between frames: 0.006081819534301758 seconds
# Time between frames: 0.005239009857177734 seconds
# Time between frames: 0.005776643753051758 seconds
# Time between frames: 0.005214214324951172 seconds
# Time between frames: 0.005191326141357422 seconds
# Time between frames: 0.005980253219604492 seconds
# Time between frames: 0.005131244659423828 seconds
# Time between frames: 0.005688667297363281 seconds
# Time between frames: 0.00506901741027832 seconds
# Time between frames: 0.006105184555053711 seconds
# Time between frames: 0.006798744201660156 seconds
# Time between frames: 0.0065424442291259766 seconds
# Time between frames: 0.05866527557373047 seconds
# Time between frames: 0.006495475769042969 seconds
# Time between frames: 0.006353616714477539 seconds
# Time between frames: 0.006287813186645508 seconds
# Time between frames: 0.006068706512451172 seconds
# Time between frames: 0.0068433284759521484 seconds
# Time between frames: 0.00625920295715332 seconds
# Time between frames: 0.0066301822662353516 seconds
# Time between frames: 0.00557398796081543 seconds
# Time between frames: 0.005460262298583984 seconds
# Time between frames: 0.005741119384765625 seconds
# Time between frames: 0.006062746047973633 seconds
# Time between frames: 0.005865335464477539 seconds
# Time between frames: 0.0067806243896484375 seconds
# Time between frames: 0.006824493408203125 seconds
# Time between frames: 0.0066645145416259766 seconds
# Time between frames: 0.005453824996948242 seconds
# Time between frames: 0.005562305450439453 seconds
# Time between frames: 0.005501508712768555 seconds
# Time between frames: 0.005526065826416016 seconds
# Time between frames: 0.006258249282836914 seconds
# Time between frames: 0.0066721439361572266 seconds
# Time between frames: 0.005814790725708008 seconds
# Time between frames: 0.0050525665283203125 seconds
# Time between frames: 0.005136013031005859 seconds
# Time between frames: 0.004976987838745117 seconds
# Time between frames: 0.005625009536743164 seconds
# Time between frames: 0.005159616470336914 seconds
# Time between frames: 0.005518674850463867 seconds
# Time between frames: 0.005930662155151367 seconds
# Time between frames: 0.005547046661376953 seconds
# Time between frames: 0.006048679351806641 seconds
# Time between frames: 0.004773855209350586 seconds
# Time between frames: 0.005039691925048828 seconds
# Time between frames: 0.005799770355224609 seconds
# Time between frames: 0.0057981014251708984 seconds
# Time between frames: 0.005043983459472656 seconds
# Time between frames: 0.0051250457763671875 seconds
# Time between frames: 0.00542449951171875 seconds
# Time between frames: 0.00570225715637207 seconds
# Time between frames: 0.0062372684478759766 seconds
# Time between frames: 0.0050122737884521484 seconds
# Time between frames: 0.0051097869873046875 seconds
# Time between frames: 0.005839347839355469 seconds
# Time between frames: 0.005366802215576172 seconds
# Time between frames: 0.00560450553894043 seconds
# Time between frames: 0.005165576934814453 seconds
# Time between frames: 0.005657196044921875 seconds
# Time between frames: 0.005831718444824219 seconds
# Time between frames: 0.0052013397216796875 seconds
# Time between frames: 0.004979372024536133 seconds
# Time between frames: 0.005043506622314453 seconds
# Time between frames: 0.0057830810546875 seconds
# Time between frames: 0.005469560623168945 seconds
# Time between frames: 0.005814313888549805 seconds
# Time between frames: 0.005160808563232422 seconds
# Time between frames: 0.005391836166381836 seconds
# Time between frames: 0.005715131759643555 seconds
# Time between frames: 0.005894184112548828 seconds
# Time between frames: 0.006227254867553711 seconds
# Time between frames: 0.0054552555084228516 seconds
# Time between frames: 0.00539088249206543 seconds
# Time between frames: 0.005476951599121094 seconds
# Time between frames: 0.005702018737792969 seconds
# Time between frames: 0.006140947341918945 seconds
# Time between frames: 0.0063974857330322266 seconds
# Time between frames: 0.005257129669189453 seconds
# Time between frames: 0.005236387252807617 seconds
# Time between frames: 0.006881237030029297 seconds
# Time between frames: 0.007119178771972656 seconds
# Time between frames: 0.005364418029785156 seconds
# Time between frames: 0.007784605026245117 seconds
# Time between frames: 0.0063288211822509766 seconds
# Time between frames: 0.00594782829284668 seconds
# Time between frames: 0.0062520503997802734 seconds
# Time between frames: 0.006036281585693359 seconds
# Time between frames: 0.005425930023193359 seconds
# Time between frames: 0.005682945251464844 seconds
# Time between frames: 0.00537109375 seconds
# Time between frames: 0.005465507507324219 seconds
# Time between frames: 0.00635528564453125 seconds
# Time between frames: 0.005429983139038086 seconds
# Time between frames: 0.006087064743041992 seconds
# Time between frames: 0.0053691864013671875 seconds
# Time between frames: 0.005614519119262695 seconds
# Time between frames: 0.005753278732299805 seconds
# Time between frames: 0.006258726119995117 seconds
# Time between frames: 0.005031108856201172 seconds
# Time between frames: 0.005280017852783203 seconds
# Time between frames: 0.005273103713989258 seconds
# Time between frames: 0.00570225715637207 seconds
# Time between frames: 0.005138874053955078 seconds
# Time between frames: 0.005410671234130859 seconds
# Time between frames: 0.0057942867279052734 seconds
# Time between frames: 0.0053081512451171875 seconds
# Time between frames: 0.006223440170288086 seconds
# Time between frames: 0.006012439727783203 seconds
# Time between frames: 0.0054090023040771484 seconds
# Time between frames: 0.005491971969604492 seconds
# Time between frames: 0.0059626102447509766 seconds
# Time between frames: 0.005434751510620117 seconds
# Time between frames: 0.0062868595123291016 seconds
# Time between frames: 0.006264448165893555 seconds
# Time between frames: 0.005320072174072266 seconds
# Time between frames: 0.0056002140045166016 seconds
# Time between frames: 0.00595855712890625 seconds
# Time between frames: 0.005267620086669922 seconds
# Time between frames: 0.006068706512451172 seconds
# Time between frames: 0.005282878875732422 seconds
# Time between frames: 0.0050165653228759766 seconds
# Time between frames: 0.00566864013671875 seconds
# Time between frames: 0.005570650100708008 seconds
# Time between frames: 0.007828712463378906 seconds
# Time between frames: 0.006493806838989258 seconds
# Time between frames: 0.007403850555419922 seconds
# Time between frames: 0.0076732635498046875 seconds
# Time between frames: 0.006136178970336914 seconds
# Time between frames: 0.006751537322998047 seconds
# Time between frames: 0.006258487701416016 seconds
# Time between frames: 0.006712913513183594 seconds
# Time between frames: 0.0067670345306396484 seconds
# Time between frames: 0.006622314453125 seconds
# Time between frames: 0.007210969924926758 seconds
# Time between frames: 0.006571769714355469 seconds
# Time between frames: 0.0057849884033203125 seconds
# Time between frames: 0.006170034408569336 seconds
# Time between frames: 0.007058382034301758 seconds
# Time between frames: 0.009543180465698242 seconds
# Time between frames: 0.00689244270324707 seconds
# Time between frames: 0.006772041320800781 seconds
# Time between frames: 0.006971597671508789 seconds
# Time between frames: 0.0061550140380859375 seconds
# Time between frames: 0.0060427188873291016 seconds
# Time between frames: 0.005439043045043945 seconds
# Time between frames: 0.0058519840240478516 seconds
# Time between frames: 0.007225751876831055 seconds
# Time between frames: 0.0061910152435302734 seconds
# Time between frames: 0.00581812858581543 seconds
# Time between frames: 0.006676197052001953 seconds
# Time between frames: 0.006304264068603516 seconds
# Time between frames: 0.006912708282470703 seconds
# Time between frames: 0.006924867630004883 seconds
# Time between frames: 0.006182193756103516 seconds
# Time between frames: 0.006096839904785156 seconds
# Time between frames: 0.005984067916870117 seconds
# Time between frames: 0.00573277473449707 seconds
# Time between frames: 0.005639314651489258 seconds
# Time between frames: 0.005096435546875 seconds
# Time between frames: 0.006419658660888672 seconds
# Time between frames: 0.005333423614501953 seconds
# Time between frames: 0.005120754241943359 seconds
# Time between frames: 0.005946159362792969 seconds
# Time between frames: 0.00508880615234375 seconds
# Time between frames: 0.005881071090698242 seconds
# Time between frames: 0.004983663558959961 seconds
# Time between frames: 0.00534510612487793 seconds
# Time between frames: 0.005433559417724609 seconds
# Time between frames: 0.006020545959472656 seconds
# Time between frames: 0.0062749385833740234 seconds
# Time between frames: 0.005179166793823242 seconds
# Time between frames: 0.00523066520690918 seconds
# Time between frames: 0.0057718753814697266 seconds
# Time between frames: 0.005242586135864258 seconds
# Time between frames: 0.0060117244720458984 seconds
# Time between frames: 0.005098104476928711 seconds
# Time between frames: 0.005413055419921875 seconds
# Time between frames: 0.005603790283203125 seconds
# Time between frames: 0.005388498306274414 seconds
# Time between frames: 0.0050351619720458984 seconds
# Time between frames: 0.004920482635498047 seconds
# Time between frames: 0.0058100223541259766 seconds
# Time between frames: 0.005167245864868164 seconds
# Time between frames: 0.0048372745513916016 seconds
# Time between frames: 0.004842519760131836 seconds
# Time between frames: 0.005158185958862305 seconds
# Time between frames: 0.0062406063079833984 seconds
# Time between frames: 0.00639796257019043 seconds
# Time between frames: 0.005055665969848633 seconds
# Time between frames: 0.004987955093383789 seconds
# Time between frames: 0.005616903305053711 seconds
# Time between frames: 0.0054056644439697266 seconds
# Time between frames: 0.004935741424560547 seconds
# Time between frames: 0.005099773406982422 seconds
# Time between frames: 0.005679130554199219 seconds
# Time between frames: 0.005235910415649414 seconds
# Time between frames: 0.006250619888305664 seconds
# Time between frames: 0.005690097808837891 seconds
# Time between frames: 0.005236625671386719 seconds
# Time between frames: 0.0059108734130859375 seconds
# Time between frames: 0.005337238311767578 seconds
# Time between frames: 0.005854368209838867 seconds
# Time between frames: 0.005524158477783203 seconds
# Time between frames: 0.008841276168823242 seconds
# Time between frames: 0.005770444869995117 seconds
# Time between frames: 0.005143880844116211 seconds
# Time between frames: 0.00563812255859375 seconds
# Time between frames: 0.005615949630737305 seconds
# Time between frames: 0.006561994552612305 seconds
# Time between frames: 0.00657200813293457 seconds
# Time between frames: 0.00528407096862793 seconds
# Time between frames: 0.005477190017700195 seconds
# Time between frames: 0.005608797073364258 seconds
# Time between frames: 0.006070852279663086 seconds
# Time between frames: 0.005529642105102539 seconds
# Time between frames: 0.005798816680908203 seconds
# Time between frames: 0.0051081180572509766 seconds
# Time between frames: 0.005120038986206055 seconds
# Time between frames: 0.005892753601074219 seconds
# Time between frames: 0.005282878875732422 seconds
# Time between frames: 0.005986213684082031 seconds
# Time between frames: 0.005131959915161133 seconds
# Time between frames: 0.0056018829345703125 seconds
# Time between frames: 0.006157398223876953 seconds
# Time between frames: 0.005666971206665039 seconds
# Time between frames: 0.0059392452239990234 seconds
# Time between frames: 0.006119251251220703 seconds
# Time between frames: 0.0049855709075927734 seconds
# Time between frames: 0.0057830810546875 seconds
# Time between frames: 0.005742549896240234 seconds
# Time between frames: 0.005521535873413086 seconds
# Time between frames: 0.0063326358795166016 seconds
# Time between frames: 0.005337953567504883 seconds
# Time between frames: 0.004975080490112305 seconds
# Time between frames: 0.006086111068725586 seconds
# Time between frames: 0.005961894989013672 seconds
# Time between frames: 0.0055196285247802734 seconds
# Time between frames: 0.005324125289916992 seconds
# Time between frames: 0.005429744720458984 seconds
# Time between frames: 0.0059278011322021484 seconds
# Time between frames: 0.008224725723266602 seconds
# Time between frames: 0.008986949920654297 seconds
# Time between frames: 0.009177207946777344 seconds
# Time between frames: 0.007852315902709961 seconds
# Time between frames: 0.0056264400482177734 seconds
# Time between frames: 0.006077766418457031 seconds
# Time between frames: 0.005203962326049805 seconds
# Time between frames: 0.005537748336791992 seconds
# Time between frames: 0.005946636199951172 seconds
# Time between frames: 0.006102085113525391 seconds
# Time between frames: 0.005440473556518555 seconds
# Time between frames: 0.006265878677368164 seconds
# Time between frames: 0.005322456359863281 seconds
# Time between frames: 0.004920244216918945 seconds
# Time between frames: 0.005637168884277344 seconds
# Time between frames: 0.005179643630981445 seconds
# Time between frames: 0.006058216094970703 seconds
# Time between frames: 0.004951953887939453 seconds
# Time between frames: 0.006011247634887695 seconds
# Time between frames: 0.0061571598052978516 seconds
# Time between frames: 0.00554966926574707 seconds
# Time between frames: 0.005688667297363281 seconds
# Time between frames: 0.0051157474517822266 seconds
# Time between frames: 0.005255460739135742 seconds
# Time between frames: 0.005530118942260742 seconds
# Time between frames: 0.006203174591064453 seconds
# Time between frames: 0.006607770919799805 seconds
# Time between frames: 0.0069468021392822266 seconds
# Time between frames: 0.006609201431274414 seconds
# Time between frames: 0.006277561187744141 seconds
# Time between frames: 0.005170583724975586 seconds
# Time between frames: 0.0050585269927978516 seconds
# Time between frames: 0.0056531429290771484 seconds
# Time between frames: 0.006223201751708984 seconds
# Time between frames: 0.0065059661865234375 seconds
# Time between frames: 0.00621342658996582 seconds
# Time between frames: 0.006372928619384766 seconds
# Time between frames: 0.00521087646484375 seconds
# Time between frames: 0.005102396011352539 seconds
# Time between frames: 0.0056912899017333984 seconds
# Time between frames: 0.005916595458984375 seconds
# Time between frames: 0.0069713592529296875 seconds
# Time between frames: 0.006888866424560547 seconds
# Time between frames: 0.0067255496978759766 seconds
# Time between frames: 0.00687098503112793 seconds
# Time between frames: 0.00610661506652832 seconds
# Time between frames: 0.00545811653137207 seconds
# Time between frames: 0.005159854888916016 seconds
# Time between frames: 0.005433797836303711 seconds
# Time between frames: 0.0063800811767578125 seconds
# Time between frames: 0.006735563278198242 seconds
# Time between frames: 0.006427288055419922 seconds
# Time between frames: 0.0065457820892333984 seconds
# Time between frames: 0.005372762680053711 seconds
# Time between frames: 0.0050601959228515625 seconds
# Time between frames: 0.005129575729370117 seconds
# Time between frames: 0.0062711238861083984 seconds
# Time between frames: 0.006431102752685547 seconds
# Time between frames: 0.007206916809082031 seconds
# Time between frames: 0.007058382034301758 seconds
# Time between frames: 0.006830692291259766 seconds
# Time between frames: 0.0068399906158447266 seconds
# Time between frames: 0.006791830062866211 seconds
# Time between frames: 0.006196498870849609 seconds
# Time between frames: 0.005397796630859375 seconds
# Time between frames: 0.0059511661529541016 seconds
# Time between frames: 0.005327939987182617 seconds
# Time between frames: 0.005530834197998047 seconds
# Time between frames: 0.006161928176879883 seconds
# Time between frames: 0.005365133285522461 seconds
# Time between frames: 0.005617380142211914 seconds
# Time between frames: 0.0052356719970703125 seconds
# Time between frames: 0.005219221115112305 seconds
# Time between frames: 0.005996227264404297 seconds
# Time between frames: 0.005316972732543945 seconds
# Time between frames: 0.0052907466888427734 seconds
# Time between frames: 0.005206108093261719 seconds
# Time between frames: 0.005795001983642578 seconds
# Time between frames: 0.006720542907714844 seconds
# Time between frames: 0.00675654411315918 seconds
# Time between frames: 0.0063784122467041016 seconds
# Time between frames: 0.005129098892211914 seconds
# Time between frames: 0.004964590072631836 seconds
# Time between frames: 0.005334138870239258 seconds
# Time between frames: 0.006366729736328125 seconds
# Time between frames: 0.006796360015869141 seconds
# Time between frames: 0.006392240524291992 seconds
# Time between frames: 0.005215883255004883 seconds
# Time between frames: 0.004960298538208008 seconds
# Time between frames: 0.005032777786254883 seconds
# Time between frames: 0.005914449691772461 seconds
# Time between frames: 0.006873130798339844 seconds
# Time between frames: 0.006675243377685547 seconds
# Time between frames: 0.005415916442871094 seconds
# Time between frames: 0.0052034854888916016 seconds
# Time between frames: 0.005188465118408203 seconds
# Time between frames: 0.005579471588134766 seconds
# Time between frames: 0.006510496139526367 seconds
# Time between frames: 0.005245685577392578 seconds
# Time between frames: 0.005049228668212891 seconds
# Time between frames: 0.0052378177642822266 seconds
# Time between frames: 0.0053768157958984375 seconds
# Time between frames: 0.0052013397216796875 seconds
# Time between frames: 0.005159616470336914 seconds
# Time between frames: 0.0051538944244384766 seconds
# Time between frames: 0.005388736724853516 seconds
# Time between frames: 0.0051746368408203125 seconds
# Time between frames: 0.005190610885620117 seconds
# Time between frames: 0.005353212356567383 seconds
# Time between frames: 0.005448341369628906 seconds
# Time between frames: 0.006272554397583008 seconds
# Time between frames: 0.005360126495361328 seconds
# Time between frames: 0.005504131317138672 seconds
# Time between frames: 0.0055446624755859375 seconds
# Time between frames: 0.005369901657104492 seconds
# Time between frames: 0.006286144256591797 seconds
# Time between frames: 0.005334377288818359 seconds
# Time between frames: 0.005207538604736328 seconds
# Time between frames: 0.005128145217895508 seconds
# Time between frames: 0.005324602127075195 seconds
# Time between frames: 0.006400108337402344 seconds
# Time between frames: 0.0051610469818115234 seconds
# Time between frames: 0.005164146423339844 seconds
# Time between frames: 0.007750034332275391 seconds
# Time between frames: 0.005809783935546875 seconds
# Time between frames: 0.0054149627685546875 seconds
# Time between frames: 0.0060656070709228516 seconds
# Time between frames: 0.005837440490722656 seconds
# Time between frames: 0.005320072174072266 seconds
# Time between frames: 0.005369901657104492 seconds
# Time between frames: 0.005526065826416016 seconds
# Time between frames: 0.005749225616455078 seconds
# Time between frames: 0.00620579719543457 seconds
# Time between frames: 0.005231380462646484 seconds
# Time between frames: 0.005204916000366211 seconds
# Time between frames: 0.005625009536743164 seconds
# Time between frames: 0.005621671676635742 seconds
# Time between frames: 0.006102561950683594 seconds
# Time between frames: 0.005411863327026367 seconds
# Time between frames: 0.005419015884399414 seconds
# Time between frames: 0.005466938018798828 seconds
# Time between frames: 0.0060307979583740234 seconds
# Time between frames: 0.006089925765991211 seconds
# Time between frames: 0.006110191345214844 seconds
# Time between frames: 0.00554966926574707 seconds
# Time between frames: 0.0055844783782958984 seconds
# Time between frames: 0.005646944046020508 seconds
# Time between frames: 0.006204366683959961 seconds
# Time between frames: 0.006055116653442383 seconds
# Time between frames: 0.006423234939575195 seconds
# Time between frames: 0.005484342575073242 seconds
# Time between frames: 0.005301237106323242 seconds
# Time between frames: 0.005761861801147461 seconds
# Time between frames: 0.006123065948486328 seconds
# Time between frames: 0.005625009536743164 seconds
# Time between frames: 0.0060117244720458984 seconds
# Time between frames: 0.0052356719970703125 seconds
# Time between frames: 0.005396127700805664 seconds
# Time between frames: 0.005628108978271484 seconds
# Time between frames: 0.005919694900512695 seconds
# Time between frames: 0.006145954132080078 seconds
# Time between frames: 0.006140708923339844 seconds
# Time between frames: 0.00540614128112793 seconds
# Time between frames: 0.005958080291748047 seconds
# Time between frames: 0.00792074203491211 seconds
# Time between frames: 0.005565643310546875 seconds
# Time between frames: 0.0056531429290771484 seconds
# Time between frames: 0.005906343460083008 seconds
# Time between frames: 0.00600886344909668 seconds
# Time between frames: 0.005011558532714844 seconds
# Time between frames: 0.005102634429931641 seconds
# Time between frames: 0.0052034854888916016 seconds
# Time between frames: 0.005171775817871094 seconds
# Time between frames: 0.0049593448638916016 seconds
# Time between frames: 0.005055904388427734 seconds
# Time between frames: 0.005581855773925781 seconds
# Time between frames: 0.005445003509521484 seconds
# Time between frames: 0.00531005859375 seconds
# Time between frames: 0.005387544631958008 seconds
# Time between frames: 0.005246639251708984 seconds
# Time between frames: 0.00658869743347168 seconds
# Time between frames: 0.006913900375366211 seconds
# Time between frames: 0.005394935607910156 seconds
# Time between frames: 0.0052776336669921875 seconds
# Time between frames: 0.005630016326904297 seconds
# Time between frames: 0.0057125091552734375 seconds
# Time between frames: 0.005835294723510742 seconds
# Time between frames: 0.005883693695068359 seconds
# Time between frames: 0.006296634674072266 seconds
# Time between frames: 0.0062410831451416016 seconds
# Time between frames: 0.0051422119140625 seconds
# Time between frames: 0.005535125732421875 seconds
# Time between frames: 0.005576372146606445 seconds
# Time between frames: 0.005325794219970703 seconds
# Time between frames: 0.005300998687744141 seconds
# Time between frames: 0.005120992660522461 seconds
# Time between frames: 0.005341529846191406 seconds
# Time between frames: 0.0062329769134521484 seconds
# Time between frames: 0.005737781524658203 seconds
# Time between frames: 0.0074193477630615234 seconds
# Time between frames: 0.007838010787963867 seconds
# Time between frames: 0.006986141204833984 seconds
# Time between frames: 0.0071256160736083984 seconds
# Time between frames: 0.0057220458984375 seconds
# Time between frames: 0.0064547061920166016 seconds
# Time between frames: 0.005339145660400391 seconds
# Time between frames: 0.005503416061401367 seconds
# Time between frames: 0.005447864532470703 seconds
# Time between frames: 0.006235599517822266 seconds
# Time between frames: 0.005873441696166992 seconds
# Time between frames: 0.006276607513427734 seconds
# Time between frames: 0.005337238311767578 seconds
# Time between frames: 0.005420207977294922 seconds
# Time between frames: 0.005439043045043945 seconds
# Time between frames: 0.006312847137451172 seconds
# Time between frames: 0.005555629730224609 seconds
# Time between frames: 0.006104707717895508 seconds
# Time between frames: 0.005313396453857422 seconds
# Time between frames: 0.005521059036254883 seconds
# Time between frames: 0.00571751594543457 seconds
# Time between frames: 0.006178379058837891 seconds
# Time between frames: 0.005725383758544922 seconds
# Time between frames: 0.005193948745727539 seconds
# Time between frames: 0.005161762237548828 seconds
# Time between frames: 0.005823612213134766 seconds
# Time between frames: 0.0061223506927490234 seconds
# Time between frames: 0.005554914474487305 seconds
# Time between frames: 0.005194425582885742 seconds
# Time between frames: 0.0049932003021240234 seconds
# Time between frames: 0.00544428825378418 seconds
# Time between frames: 0.005237102508544922 seconds
# Time between frames: 0.005123615264892578 seconds
# Time between frames: 0.0051631927490234375 seconds
# Time between frames: 0.00552058219909668 seconds
# Time between frames: 0.005565643310546875 seconds
# Time between frames: 0.0059070587158203125 seconds
# Time between frames: 0.0053212642669677734 seconds
# Time between frames: 0.005448341369628906 seconds
# Time between frames: 0.0056400299072265625 seconds
# Time between frames: 0.006163597106933594 seconds
# Time between frames: 0.005947113037109375 seconds
# Time between frames: 0.006280422210693359 seconds
# Time between frames: 0.005362272262573242 seconds
# Time between frames: 0.0055959224700927734 seconds
# Time between frames: 0.005608797073364258 seconds
# Time between frames: 0.006226062774658203 seconds
# Time between frames: 0.005856990814208984 seconds
# Time between frames: 0.0053768157958984375 seconds
# Time between frames: 0.005265235900878906 seconds
# Time between frames: 0.005379676818847656 seconds
# Time between frames: 0.0057718753814697266 seconds
# Time between frames: 0.005711078643798828 seconds
# Time between frames: 0.0059087276458740234 seconds
# Time between frames: 0.005017995834350586 seconds
# Time between frames: 0.005151033401489258 seconds
# Time between frames: 0.0057713985443115234 seconds
# Time between frames: 0.005999565124511719 seconds
# Time between frames: 0.006112098693847656 seconds
# Time between frames: 0.005281686782836914 seconds
# Time between frames: 0.005402326583862305 seconds
# Time between frames: 0.0057833194732666016 seconds
# Time between frames: 0.005939960479736328 seconds
# Time between frames: 0.005886077880859375 seconds
# Time between frames: 0.006089210510253906 seconds
# Time between frames: 0.005143880844116211 seconds
# Time between frames: 0.005126953125 seconds
# Time between frames: 0.00600123405456543 seconds
# Time between frames: 0.005425691604614258 seconds
# Time between frames: 0.0050961971282958984 seconds
# Time between frames: 0.0051496028900146484 seconds
# Time between frames: 0.0055921077728271484 seconds
# Time between frames: 0.006117582321166992 seconds
# Time between frames: 0.005834817886352539 seconds
# Time between frames: 0.005990266799926758 seconds
# Time between frames: 0.0051076412200927734 seconds
# Time between frames: 0.0052051544189453125 seconds
# Time between frames: 0.006111860275268555 seconds
# Time between frames: 0.005234956741333008 seconds
# Time between frames: 0.0049800872802734375 seconds
# Time between frames: 0.005059242248535156 seconds
# Time between frames: 0.00555419921875 seconds
# Time between frames: 0.005135536193847656 seconds
# Time between frames: 0.004956245422363281 seconds
# Time between frames: 0.005147218704223633 seconds
# Time between frames: 0.005821704864501953 seconds
# Time between frames: 0.00520014762878418 seconds
# Time between frames: 0.0050127506256103516 seconds
# Time between frames: 0.005032539367675781 seconds
# Time between frames: 0.0054166316986083984 seconds
# Time between frames: 0.005087852478027344 seconds
# Time between frames: 0.0051195621490478516 seconds
# Time between frames: 0.0050525665283203125 seconds
# Time between frames: 0.005628824234008789 seconds
# Time between frames: 0.005291938781738281 seconds
# Time between frames: 0.00522160530090332 seconds
# Time between frames: 0.005022764205932617 seconds
# Time between frames: 0.005686044692993164 seconds
# Time between frames: 0.005957841873168945 seconds
# Time between frames: 0.0058155059814453125 seconds
# Time between frames: 0.005224466323852539 seconds
# Time between frames: 0.0052487850189208984 seconds
# Time between frames: 0.005473613739013672 seconds
# Time between frames: 0.005909919738769531 seconds
# Time between frames: 0.006100893020629883 seconds
# Time between frames: 0.006036520004272461 seconds
# Time between frames: 0.005053043365478516 seconds
# Time between frames: 0.005293130874633789 seconds
# Time between frames: 0.005782127380371094 seconds
# Time between frames: 0.0055696964263916016 seconds
# Time between frames: 0.005053520202636719 seconds
# Time between frames: 0.0055179595947265625 seconds
# Time between frames: 0.005288362503051758 seconds
# Time between frames: 0.005959510803222656 seconds
# Time between frames: 0.006217002868652344 seconds
# Time between frames: 0.006456613540649414 seconds
# Time between frames: 0.005350589752197266 seconds
# Time between frames: 0.005321502685546875 seconds
# Time between frames: 0.0053615570068359375 seconds
# Time between frames: 0.005758047103881836 seconds
# Time between frames: 0.005887031555175781 seconds
# Time between frames: 0.005280256271362305 seconds
# Time between frames: 0.005541324615478516 seconds
# Time between frames: 0.005532026290893555 seconds
# Time between frames: 0.00592494010925293 seconds
# Time between frames: 0.005336761474609375 seconds
# Time between frames: 0.004817485809326172 seconds
# Time between frames: 0.004788398742675781 seconds
# Time between frames: 0.005634307861328125 seconds
# Time between frames: 0.005698204040527344 seconds
# Time between frames: 0.005036592483520508 seconds
# Time between frames: 0.004922628402709961 seconds
# Time between frames: 0.00600743293762207 seconds
# Time between frames: 0.0054552555084228516 seconds
# Time between frames: 0.006175994873046875 seconds
# Time between frames: 0.0052797794342041016 seconds
# Time between frames: 0.005239009857177734 seconds
# Time between frames: 0.005796194076538086 seconds
# Time between frames: 0.005536794662475586 seconds
# Time between frames: 0.005118608474731445 seconds
# Time between frames: 0.005397796630859375 seconds
# Time between frames: 0.0052034854888916016 seconds
# Time between frames: 0.006166934967041016 seconds
# Time between frames: 0.00526118278503418 seconds
# Time between frames: 0.005279064178466797 seconds
# Time between frames: 0.0054416656494140625 seconds
# Time between frames: 0.005537271499633789 seconds
# Time between frames: 0.006262302398681641 seconds
# Time between frames: 0.005800485610961914 seconds
# Time between frames: 0.005953073501586914 seconds
# Time between frames: 0.005460977554321289 seconds
# Time between frames: 0.006107807159423828 seconds
# Time between frames: 0.009299278259277344 seconds
# Time between frames: 0.005403995513916016 seconds
# Time between frames: 0.005631446838378906 seconds
# Time between frames: 0.005808115005493164 seconds
# Time between frames: 0.006587028503417969 seconds
# Time between frames: 0.006105184555053711 seconds
# Time between frames: 0.005639314651489258 seconds
# Time between frames: 0.006537675857543945 seconds
# Time between frames: 0.005604982376098633 seconds
# Time between frames: 0.0051746368408203125 seconds
# Time between frames: 0.005459308624267578 seconds
# Time between frames: 0.005495786666870117 seconds
# Time between frames: 0.005981922149658203 seconds
# Time between frames: 0.00507807731628418 seconds
# Time between frames: 0.004888057708740234 seconds
# Time between frames: 0.0060045719146728516 seconds
# Time between frames: 0.0052912235260009766 seconds
# Time between frames: 0.005059957504272461 seconds
# Time between frames: 0.00507354736328125 seconds
# Time between frames: 0.005791425704956055 seconds
# Time between frames: 0.0056989192962646484 seconds
# Time between frames: 0.0058727264404296875 seconds
# Time between frames: 0.005022287368774414 seconds
# Time between frames: 0.004969120025634766 seconds
# Time between frames: 0.00576329231262207 seconds
# Time between frames: 0.005291938781738281 seconds
# Time between frames: 0.004945516586303711 seconds
# Time between frames: 0.005148410797119141 seconds
# Time between frames: 0.005573749542236328 seconds
# Time between frames: 0.005537271499633789 seconds
# Time between frames: 0.0059604644775390625 seconds
# Time between frames: 0.005171537399291992 seconds
# Time between frames: 0.005303382873535156 seconds
# Time between frames: 0.006029605865478516 seconds
# Time between frames: 0.005686521530151367 seconds
# Time between frames: 0.0064318180084228516 seconds
# Time between frames: 0.006447315216064453 seconds
# Time between frames: 0.005545854568481445 seconds
# Time between frames: 0.0055887699127197266 seconds
# Time between frames: 0.005735635757446289 seconds
# Time between frames: 0.00612187385559082 seconds
# Time between frames: 0.005540609359741211 seconds
# Time between frames: 0.005982637405395508 seconds
# Time between frames: 0.005065441131591797 seconds
# Time between frames: 0.00500178337097168 seconds
# Time between frames: 0.00594019889831543 seconds
# Time between frames: 0.005387783050537109 seconds
# Time between frames: 0.004916191101074219 seconds
# Time between frames: 0.004964351654052734 seconds
# Time between frames: 0.005833148956298828 seconds
# Time between frames: 0.005461454391479492 seconds
# Time between frames: 0.006378173828125 seconds
# Time between frames: 0.00513768196105957 seconds
# Time between frames: 0.005381107330322266 seconds
# Time between frames: 0.0057315826416015625 seconds
# Time between frames: 0.006044864654541016 seconds
# Time between frames: 0.0055887699127197266 seconds
# Time between frames: 0.00508570671081543 seconds
# Time between frames: 0.0051763057708740234 seconds
# Time between frames: 0.005563020706176758 seconds
# Time between frames: 0.005553245544433594 seconds
# Time between frames: 0.006017208099365234 seconds
# Time between frames: 0.0051116943359375 seconds
# Time between frames: 0.005251407623291016 seconds
# Time between frames: 0.005970954895019531 seconds
# Time between frames: 0.005730628967285156 seconds
# Time between frames: 0.006168365478515625 seconds
# Time between frames: 0.0051746368408203125 seconds
# Time between frames: 0.005321979522705078 seconds
# Time between frames: 0.005423784255981445 seconds
# Time between frames: 0.005771636962890625 seconds
# Time between frames: 0.006852149963378906 seconds
# Time between frames: 0.006695270538330078 seconds
# Time between frames: 0.0064239501953125 seconds
# Time between frames: 0.0050144195556640625 seconds
# Time between frames: 0.005044460296630859 seconds
# Time between frames: 0.005231618881225586 seconds
# Time between frames: 0.0058252811431884766 seconds
# Time between frames: 0.006283760070800781 seconds
# Time between frames: 0.0048367977142333984 seconds
# Time between frames: 0.004871845245361328 seconds
# Time between frames: 0.00498199462890625 seconds
# Time between frames: 0.006457090377807617 seconds
# Time between frames: 0.005235433578491211 seconds
# Time between frames: 0.005117893218994141 seconds
# Time between frames: 0.0060007572174072266 seconds
# Time between frames: 0.00578761100769043 seconds
# Time between frames: 0.006380796432495117 seconds
# Time between frames: 0.006716489791870117 seconds
# Time between frames: 0.0064067840576171875 seconds
# Time between frames: 0.005024433135986328 seconds
# Time between frames: 0.005114316940307617 seconds
# Time between frames: 0.0071489810943603516 seconds
# Time between frames: 0.006536722183227539 seconds
# Time between frames: 0.006450176239013672 seconds
# Time between frames: 0.00540924072265625 seconds
# Time between frames: 0.006631612777709961 seconds
# Time between frames: 0.0064890384674072266 seconds
# Time between frames: 0.006539344787597656 seconds
# Time between frames: 0.005493640899658203 seconds
# Time between frames: 0.005599260330200195 seconds
# Time between frames: 0.005576372146606445 seconds
# Time between frames: 0.0056951045989990234 seconds
# Time between frames: 0.0068209171295166016 seconds
# Time between frames: 0.006279706954956055 seconds
# Time between frames: 0.007169008255004883 seconds
# Time between frames: 0.007196903228759766 seconds
# Time between frames: 0.006825923919677734 seconds
# Time between frames: 0.012598276138305664 seconds

# %% [markdown]
# ## Test generate branch by stochastic policy neural network

# %%
key = jax.random.key(1234)
memory_settings = Memory_settings(50000, 4, 1, 1)
exp_pool = None

# %%
# Let's generate some observations and rewards

def reshape_data(datas, batch_size, fock_size):
    def fn(data):
        new_shape = [*(data.shape)][1:]
        new_shape[0]=batch_size*fock_size
        # print(new_shape)
        return data.reshape(new_shape)
    return jax.tree.map(fn,datas)



init_batch_size = 100
batch_size = init_batch_size
fock_size = 10

# Start with the fixed init state
keys = jax.random.split(key, batch_size)
datas = reset(mjx_model,batch_size)


# print(datas.qpos)
for i in range(10):    # For 2 seconds
    datas, keys, exp = jit_v_nn_multi_steps(controller_params, mjx_model, datas, keys)
    # print(datas.qvel.shape, datas.ten_J.shape)
    if(i == 2):    # After 0.5 seconds fock the simulation
        keys = jax.vmap(jax.random.split, in_axes=(0,None))(keys, fock_size)
        datas, keys, exp = jit_vv_nn_multi_steps(controller_params, mjx_model, datas, keys)
        keys = keys.reshape(batch_size*fock_size)
        datas = reshape_data(datas, batch_size, fock_size)
        exp = reshape_data(exp, batch_size, fock_size)
        # print(datas.qvel.shape, datas.ten_J.shape)
        batch_size = batch_size*fock_size
    exp_pool = Memory.add_exp(memory_settings, exp_pool, exp)

# %%
import matplotlib.pyplot as plt
# print(exp_pool)
print(exp_pool.states.shape)
key = jax.random.split(key, 1)[0]
batch = Memory.sample(exp_pool, 100, key)
key = jax.random.split(key, 1)[0]
print(batch.states[:,0:2].shape)
print(datas.qpos.shape)
plt.plot(exp_pool.states.T[1])
plt.plot(exp_pool.rewards)
# Out:
# (41000, 4)
# (100, 2)
# (1000, 2)

# %% [markdown]
# ## Train the critic neural network with generated data

# %%
import flax.linen


v_critic = jax.vmap(critic.apply,in_axes=(None, 0))


def critic_loss(params, batch):
    discount = 0.95
    states = batch.states
    next_states = batch.next_states
    actions = batch.actions
    rewards = batch.rewards
    
    critic_score = v_critic(params, states)
    target = rewards + discount* critic.apply(params, next_states)
    
    loss = optax.l2_loss(critic_score, target)
    loss = jp.mean(loss)
    return loss
    
jit_critic_loss_value = jax.jit(jax.value_and_grad(critic_loss))

# %%
# Reset Critic_NN parameters
critic_params = critic.init(key, jp.empty([1,mjx_model.nq*2]))
tx = optax.adam(learning_rate=0.00002)
opt_state = tx.init(critic_params)
jit_tx_update = jax.jit(tx.update)
jit_apply_update = jax.jit(optax.apply_updates)

# %%
for i in range(2000):
    batch = Memory.sample(exp_pool, 40, key)
    key = jax.random.split(key, 1)[0]
    loss, loss_grad = jit_critic_loss_value(critic_params, batch)
    print(loss)
    # Update params
    updates, opt_stats = jit_tx_update(loss_grad, opt_state)
    critic_params = jit_apply_update(critic_params, updates)
# Out:
# ---------------------------------------------------------------------------
# ScopeParamShapeError                      Traceback (most recent call last)
# Cell In[41], line 4
#       2 batch = Memory.sample(exp_pool, 40, key)
#       3 key = jax.random.split(key, 1)[0]
# ----> 4 loss, loss_grad = jit_critic_loss_value(critic_params, batch)
#       5 print(loss)
#       6 # Update params
#
#     [... skipping hidden 19 frame]
#
# Cell In[32], line 14, in critic_loss(params, batch)
#      11 actions = batch.actions
#      12 rewards = batch.rewards
# ---> 14 critic_score = v_critic(params, states)
#      15 target = rewards + discount* critic.apply(params, next_states)
#      17 loss = optax.l2_loss(critic_score, target)
#
#     [... skipping hidden 9 frame]
#
# Cell In[3], line 64, in Critic_NN.__call__(self, x)
#      62 x = self.linear4(x)
#      63 x = nn.relu(x)
# ---> 64 x = self.linear5(x)
#      65 # The last layer of the neural requires samping
#      66 return -nn.relu(x)
#
#     [... skipping hidden 2 frame]
#
# File ~/anaconda3/envs/biomujoco/lib/python3.11/site-packages/flax/linen/linear.py:251, in Dense.__call__(self, inputs)
#     241 @compact
#     242 def __call__(self, inputs: Array) -> Array:
#     243   """Applies a linear transformation to the inputs along the last dimension.
#     244
#     245   Args:
#    (...)
#     249     The transformed input.
#     250   """
# --> 251   kernel = self.param(
#     252     'kernel',
#     253     self.kernel_init,
#     254     (jnp.shape(inputs)[-1], self.features),
#     255     self.param_dtype,
#     256   )
#     257   if self.use_bias:
#     258     bias = self.param(
#     259       'bias', self.bias_init, (self.features,), self.param_dtype
#     260     )
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/biomujoco/lib/python3.11/site-packages/flax/core/scope.py:960, in Scope.param(self, name, init_fn, unbox, *init_args, **init_kwargs)
#     955   for val, abs_val in zip(value_flat, abs_value_flat):
#     956     # NOTE: We could check dtype consistency here as well but it's
#     957     # usefuleness is less obvious. We might intentionally change the dtype
#     958     # for inference to a half float type for example.
#     959     if jnp.shape(val) != jnp.shape(abs_val):
# --> 960       raise errors.ScopeParamShapeError(
#     961         name, self.path_text, jnp.shape(abs_val), jnp.shape(val)
#     962       )
#     963 else:
#     964   if not self.is_mutable_collection('params'):
#
# ScopeParamShapeError: Initializer expected to generate shape (400, 2) but got shape (400, 1) instead for parameter "kernel" in "/linear5". (https://flax.readthedocs.io/en/latest/api_reference/flax.errors.html#flax.errors.ScopeParamShapeError)

# %% [markdown]
# ### Test the critic neural network

# %%
jit_v_critic = jax.jit(v_critic)
test_states = exp_pool.states

# test_states = test_states.at[:,0].set(jp.zeros(test_states.shape[0]))
test_states = test_states.at[:,1].set(jp.zeros(test_states.shape[0]))
test_states = test_states.at[:,2].set(jp.zeros(test_states.shape[0]))
test_states = test_states.at[:,3].set(jp.zeros(test_states.shape[0]))
scores = jit_v_critic(critic_params, exp_pool.states)
test_scores = jit_v_critic(critic_params, test_states)

plt.plot(scores)
plt.plot(test_scores)

# %% [markdown]
# ## Train the controller with the critic net without the differentiable simulator

# %%
# Reset Params
controller_params = controller.init(key,jp.empty([1, mjx_model.nq*2]),sub_keys[0])
tx = optax.adam(learning_rate=0.00001)
opt_state = tx.init(controller_params)
jit_tx_update = jax.jit(tx.update)
jit_apply_update = jax.jit(optax.apply_updates)
batch_size = 400
# Init data

# %%
v_controller = jax.vmap(controller.apply,in_axes=(None, 0))


def total_loss(controller_params, critic_params, batch, batch_size, mjx_model, keys):
    # batch_size = batch.states.shape[0]
    states = batch.states
    # Generate data for simulation
    in_data = reset(mjx_model, batch_size).replace(qpos = states[:,0:2], qvel = states[:,2:4])
    out_data, keys, exp = jit_v_nn_multi_steps(controller_params, mjx_model, in_data, keys)
    out_states = jp.stack([out_data.qpos, out_data.qvel], axis=1).reshape(batch_size,4)
    # jax.debug.print("out_states shape{0}", out_states.shape)
    critic_score = v_critic(critic_params, out_states)
    
    loss = -jp.mean(critic_score)
    return loss

jit_total_loss_grad_value = jax.jit(jax.value_and_grad(total_loss), static_argnames=["batch_size"])

# Test total_lose
# batch_size = 100
# batch = Memory.sample(exp_pool, batch_size, key)
# key = jax.random.split(key, 1)[0]
# keys = jax.random.split(key,batch_size)
# jit_total_loss = jax.jit(total_loss, static_argnames=["batch_size"])
# loss, grad = jit_total_loss_grad_value(controller_params, critic_params, batch, batch_size, mjx_model, keys)
# print(loss)

# %%
new_params = controller_params
for i in range(100):
    batch = Memory.sample(exp_pool, batch_size, key)
    key = jax.random.split(key, 1)[0]
    keys = jax.random.split(key,batch_size)
    loss, loss_grad = jit_total_loss_grad_value(new_params, critic_params, batch, batch_size, mjx_model, keys)
    print(loss)
    # Update params
    updates, opt_stats = jit_tx_update(loss_grad, opt_state)
    new_params = jit_apply_update(new_params, updates)
# Out:
# 27.793549
# 28.631569
# 30.472363
# 28.019243
# 29.76126
# 31.52638
# 27.644316
# 26.868107
# 26.9508
# 29.097687
# 27.744448
# 28.509914
# 27.001589
# 27.688337
# 25.459991
# 24.753479
# 28.4352
# 28.4279
# 27.304207
# 27.022865
# 27.217026
# 29.237715
# 27.270586
# 26.39158
# 26.972946
# 28.41149
# 27.269331
# 26.11465
# 27.532305
# 28.19431
# 26.867943
# 26.972979
# 27.924433
# 26.189932
# 27.235023
# 29.136942
# 28.501003
# 25.939466
# 27.707998
# 27.908726
# 26.52309
# 25.341005
# 25.73312
# 26.171953
# 25.930841
# 27.587149
# 24.957235
# 25.106813
# 25.03037
# 24.919916
# 24.780863
# 26.874933
# 26.0326
# 25.518812
# 25.289528
# 26.542788
# 25.09934
# 24.707357
# 26.664536
# 27.543056
# 25.314222
# 26.883247
# 24.777353
# 25.79742
# 26.592447
# 25.404291
# 26.016874
# 23.595896
# 25.225206
# 25.743176
# 24.109995
# 23.923523
# 26.071196
# 25.372854
# 25.916391
# 23.53854
# 27.739096
# 24.646225
# 25.332449
# 24.253803
# 24.33083
# 24.255007
# 25.474861
# 25.761694
# 26.745615
# 24.317553
# 24.377512
# 24.30416
# 23.993893
# 24.020664
# 23.187729
# 24.834085
# 22.722687
# 23.185228
# 23.763865
# 24.39781
# 26.177591
# 25.394583
# 24.475441
# 24.780922

# %%
controller_params = new_params

# %% [markdown]
# ## Train the controller with the critic net and the differentiable simulator

# %% [markdown]
# ## Short Horizon Gradient calculation

# %%
def change_shape(x):
    # print(x.shape)
    return x.reshape(batch_size*fock_size,-1) 
d = jax.tree.map(change_shape,datas)
print(d.qpos.shape)
print(datas.qpos.shape)

# %%
print(keys.shape)
kk = jax.vmap(jax.random.split, in_axes=(0,None))(keys, 5)
print(kk.shape)
k = jp.reshape(kk, jp.array(kk.shape))
print(k.shape)

[*kk.shape][1:]
# print(kk.shape)

# %% [markdown]
# ## Learn To generate Critic Neural Network

# %%
datas.qpos.shape
b = jp.stack([datas.qpos, datas.qvel], axis=1).reshape(datas.qpos.shape[0],-1)
print(b[0])
print(datas.qpos[0])
print(b.shape)

# %%
a = [[2,3,4]]
b = [6,7]
b += a
print(b)

# %%
jp.stack([datas.qpos, datas.qvel], axis=1).reshape(100,-1).shape
# Out:
# (100, 4)
